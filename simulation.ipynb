# %% [markdown]
# # Simulate the trading with historical data

# %% [markdown]
# ## Import modules and define functions

# %%
from collections import defaultdict
import robin_stocks as r
import pickle
import pandas as pd
import yfinance as yf
from datetime import date
import logging

pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',20)
pd.set_option('display.max_colwidth',100)
pd.set_option('display.width',None)

def model_1(x,buy_or_sell):
    if buy_or_sell=='buy':
        ## buy model 1: price 100 factor 1; price 20 factor 2
        return round(-1/100*x+2,2) if x<=100 else 1
    elif buy_or_sell=='sell':
        #=IF(H5<100/0.9, -0.006*H5+1.5,0.9)
        return round(-0.006*x+1.5,2) if x/0.9<=100 else 0.9
    else:
        print('wrong parameter')
        
def model_2(x,buy_or_sell):
    if buy_or_sell=='buy':
        ## buy model 1: price 100 factor 1; price 20 factor 2
        return 1
    elif buy_or_sell=='sell':
        #=IF(H5<100/0.9, -0.006*H5+1.5,0.9)
        return 0.9
    else:
        print('wrong parameter')

def two_points_line(p1,p2):
    # y= a*x+b
    a=(p2[1]-p1[1])/(p2[0]-p1[0])
    b=p1[1]-(p2[1]-p1[1])/(p2[0]-p1[0])*p1[0]
    print('a is {0}, b is {1} , y = {0}*x + {1} '.format(a,b))

def convert_df_to_list(df): # df has columns [Open, High, Low, Close, Adj Close,Volume], index is Date
    data_list=[]
    for i in range(len(df)):
        tem=df.iloc[i].tolist()[0:4]
        data_list.append(tem[0]) #open
        data_list.append(tem[1]) #high
        data_list.append(tem[2]) #low
        data_list.append(tem[3]) #close
    return data_list

# verify profit
def verify_profit(year):
    d=stockTrades[year].tradingRecords
    total_buy=0
    total_sell=0
    for key in d:
        l=d[key]
        for r in l:
            if r[0]=='buy':
                total_buy+=r[1]*key
            else:
                total_sell+=r[1]*key
    print(total_buy)
    print(total_sell)
    print('profit is, ',stockTrades[year].openShares*stockTrades[year].currentPrice+total_sell-total_buy)

# %% [markdown]
# ## Create logger

# %%
logger=logging.getLogger('simulation_trading')
logger.setLevel(logging.DEBUG)
formatter=logging.Formatter('%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s')

# file handler save logs to file
file_handler=logging.FileHandler(filename='simulation_trading.log',mode='w')
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(formatter)

# stream handler print logs on console
stream_handler=logging.StreamHandler()
stream_handler.setFormatter(formatter)

logger.addHandler(file_handler)
logger.addHandler(stream_handler)

# %% [markdown]
# # Log in

# %%
#log and lout
import getpass
account=getpass.getpass('Enter your account')
psd = getpass.getpass('Enter your password')
log=r.authentication.login('hejiakoo@gmail.com',psd)
#r.logout()
# Out:
# Enter your account ··················
# Enter your password ··············

# %% [markdown]
# ## Define the simulation class

# %%
class StockTrade:
    def __init__(self,symbol,baseAmount,discountFactor,currentPrice,initialShares,model,realtrade=False):
        """
        readltrade(bool): if realtrade ==True, will send orders to robinhood;otherwise, it's a simulation
        """
        self.realtrade=realtrade
        self.symbol=symbol
        self.baseAmount=baseAmount
        self.discountFactor=discountFactor
        self.priceRange=self.generate_price_range()
        self.buy_factor_list=self.generate_factor_list(model,'buy') # buy model
        self.sell_factor_list=self.generate_factor_list(model,'sell') # sell model
        self.buy_amount_list=self.generate_buy_amount_list()
        self.sell_amount_list=self.generate_sell_amount_list()
        self.combined_lists=self.initialize_combined_list(currentPrice)
        self.openOrders={}
        self.openShares=initialShares
        self.orderNumber=0
        self.totalMoneyBuy=self.openShares*currentPrice
        self.totalmoneySell=0
        self.max_money_needed=self.totalMoneyBuy
        self.max_loss=0
        self.currentPrice=currentPrice
        #self.profit=0
        self.tradingRecords=defaultdict(list)
        self.update_tradingRecords(currentPrice,'buy',initialShares)# update the intial buy to account
        print('initialize, bought {0} shares at {1} worth {2}'.format(initialShares,currentPrice,initialShares*currentPrice))
        self.set_order()

                
    def generate_price_range(self): # return a list
        base=100
        less=100
        more=100
        l=[100]
        while more <200:
            more=more/(1-self.discountFactor)
            l.append(round(more,2))
        while less >20:
            less=less*(1-self.discountFactor)
            l.append(round(less,2))
        return sorted(l,reverse=True)
    
    def generate_factor_list(self,model,buy_or_sell):
        return [model(x,buy_or_sell) for x in self.priceRange]        
        
    def generate_buy_amount_list(self):
        return [round(self.baseAmount*i,2) for i in self.buy_factor_list]
    def generate_sell_amount_list(self):
        return [round(self.baseAmount*i,2) for i in self.sell_factor_list]
#     def initialize_labels(self,currentPrice):
#         l=[]
#         self.labels=['buy' if i>currentPrice-10 else 'sell' for i in self.priceRange]
    def get_profit(self,currentPrice):
        return round(self.openShares*currentPrice+self.totalmoneySell-self.totalMoneyBuy,2)
    
    def get_latest_price(self): # get the latest price of this symbel
        return float(r.stocks.get_latest_price(self.symbol)[0])
    
    def initialize_combined_list(self, currentPrice):
        """
        [{'price':* ,'sell':*, 'buy':*}]  item in list,
        sell: mean if it's allowed to sell at this price. affected by lower-price position buy order
        buy: mean if it's allowed to buy at his price. Affected by higher-price position sell order
        """
        l=[] 
        for i in range(len(self.priceRange)):
            price=self.priceRange[i]
            if self.priceRange[i]>=currentPrice:
                d={'price':price,'buy':False,'buy_amount':self.buy_amount_list[i],'sell':True,'sell_amount':self.sell_amount_list[i]}
            else:
                d={'price':price,'buy':True,'buy_amount':self.buy_amount_list[i],'sell':False,'sell_amount':self.sell_amount_list[i]}
            l.append(d)
#         for price in self.priceRange:
#             if price >=currentPrice:
#                 d={'price':price,'sell':True, 'buy':False}
#             else:
#                 d={'price':price,'sell':False, 'buy':True}
#             l.append(d)
        return l       
                
    def sell_setting(self,position):

        logger.info('sell setting: ')
        price=self.priceRange[position]
        amount=self.sell_amount_list[position]
        shares=round(amount/price)
        self.check_shares_avai_for_sale(shares)
        logger.info('sell {0} shares, amount {1} at {2}'.format(shares,amount,price))
        #r.orders.order_sell_limit('TQQQ',quantity=shares,limitPrice=price,extendedHours=True)
        self.openOrders.update({'sell':[{'shares':shares,'amount':amount,'price':price,'position':position}]})
        
    def buy_setting(self,position):
        logger.info('buy setting: ')
        price=self.priceRange[position]
        amount=self.buy_amount_list[position]
        shares=round(amount/price)
        logger.info('buy {0} shares, amount {1} at {2}'.format(shares,amount,price))
        #r.orders.order_buy_limit('TQQQ',quantity=shares,limitPrice=price,extendedHours=True)
        # openOrders is a dictionary, whose keys include 'buy' and 'sell'
        self.openOrders.update({'buy':[{'shares':shares,'amount':amount,'price':price,'position':position}]})
  
    def set_order(self):
        logger.info('---------set up open orders-----------')
        for j in range(len(self.priceRange)):
            if self.combined_lists[j]['buy']==True:
                self.buy_setting(j)
                break
        for k in range(len(self.priceRange)-1,-1,-1):
            if self.combined_lists[k]['sell']==True:
                self.sell_setting(k)
                break
        if self.realtrade==True:
            self.send_orders_to_rb() # send orders to robinhood
        
    def send_orders_to_rb(self):
        logger.warning('send orders to robinhood')
        r.orders.cancel_all_stock_orders() # clean all orders
        open_orders=self.openOrders
        limit_put_args={'symbol':'TQQQ','quantity':open_orders['buy'][0]['shares'],'limitPrice':open_orders['buy'][0]['price'],'extendedHours':True}
        r.orders.order_buy_limit(**limit_put_args)  # make the limit buy order 
        limit_sell_args={'symbol':'TQQQ','quantity':open_orders['sell'][0]['shares'],'limitPrice':open_orders['sell'][0]['price'],'extendedHours':True}
        r.orders.order_sell_limit(**limit_sell_args)# make the limit sell order
        logger.warning('---confirm the orders---')
        logger.warning(r.orders.get_all_open_stock_orders()) # check the orders
    def market_buy_rb(self,shares):
        logger.warning('market buy {} shares in robinhood'.format(shares))
        market_buy_args={'symbol':self.symbol,'quantity':shares,'extendedHours':True}
        r.orders.order_buy_market(**market_buy_args)
    
    def update_tradingRecords(self,price,action,shares):
        self.tradingRecords[price].append([action,shares])
    def update_openShares(self,action,shares):
        self.openShares=self.openShares-shares if action=='sell' else self.openShares+shares
    def update_labels(self,position,action,b):
        self.combined_lists[position].update({action:b})
    def check_shares_avai_for_sale (self,shares_to_sell): 
        '''
        when not enough shares available for sale, due to price keeping moving higher, buy some shares one time
        '''
        if self.openShares<=shares_to_sell+1:
            logger.warning('-------------')
            logger.warning('current share is {}, not enough shares in hand available for sale'.format(self.openShares))
            self.increase_shares(int(2*self.baseAmount/self.currentPrice))
            logger.warning('-------------')        
        
    def increase_shares(self,shares):
        logger.warning('buy {0} shares at {1} before open the sell order'.format(shares,self.currentPrice))
        self.update_tradingRecords(self.currentPrice,'buy',shares)
        self.update_openShares('buy',shares)
        self.totalMoneyBuy+=self.currentPrice*shares
        self.update_max_money_needed()
        if self.realtrade==True:
            self.market_buy_rb(shares)
        
    def update_max_money_needed(self):
        self.max_money_needed=max(self.max_money_needed,self.totalMoneyBuy-self.totalmoneySell)
    def update_max_loss_value(self,currentPrice):
        self.max_loss=min(self.get_profit(currentPrice),self.max_loss)                  
    
    def tradeStock(self,currentPrice):
        self.currentPrice=currentPrice
        #print('profit is ,', self.get_profit(currentPrice))
        self.update_max_loss_value(currentPrice)
        if currentPrice >self.openOrders['sell'][0]['price']:
            shares,amount,price,position=self.openOrders['sell'][0].values()
            action='sell'
            logger.info('---------execute order--------')
            #print('current price is ',currentPrice)
            logger.info('before trade, current shares: {}'.format(self.openShares))
            logger.info('now price {0}, sold {1} shares at {2} worth {3}'.format(currentPrice,shares,price,amount))
            #update tradingRecords
            self.totalmoneySell+=price*shares
            self.openOrders.update({'sell':[]})  # erase the open sell order as it is fulfilled
            self.orderNumber+=1
            self.update_tradingRecords(price,action,shares)  
            self.update_openShares(action,shares)
            self.update_labels(position,'sell',False)
            self.update_labels(position+1,'buy',True)
            logger.info('after trade, current shares: {}'.format(self.openShares))
            [logger.info(i) for i in self.combined_lists]
            #print(*self.combined_lists,sep='\n')
            # open new orders
            self.set_order()
            
            
        elif currentPrice<self.openOrders['buy'][0]['price']:  # currentPrice < openOrder buy limit price
            shares,amount,price,position=self.openOrders['buy'][0].values()
            action='buy'
            logger.info('---------execute order--------')
            #print('current price is ',currentPrice)
            logger.info('before trade, current shares: {}'.format(self.openShares))
            logger.info('now price {0}, bought {1} shares at {2} worth {3}'.format(currentPrice,shares,price,amount))
            #update
            self.totalMoneyBuy+=price*shares
            self.update_max_money_needed()
            logger.info('money required {}'.format(self.max_money_needed))
            self.openOrders.update({'buy':[]}) # erase the open buy order as it is fulfilled 
            self.orderNumber+=1
            self.update_tradingRecords(price,action,shares)  
            self.update_openShares(action,shares)          
            self.update_labels(position,'buy',False)
            self.update_labels(position-1,'sell',True)
            logger.info('after trade, current shares: {}'.format(self.openShares))
            [logger.info(i) for i in self.combined_lists]
            # open new orders
            self.set_order() 
        else:
            print('---------no execute --------')

# %%
def save_object(obj,filename):
    with open(filename,'wb') as output_data:
        pickle.dump(obj,output_data,pickle.HIGHEST_PROTOCOL)

def load_object(filename):
    with open(filename,'rb') as input_data:
        obj=pickle.load(input_data)
        return obj

# %%
df=yf.download('TQQQ',start=date(2020,9,2)) #,end=date(2020,9,10)
current_list=convert_df_to_list(df)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-09-09  129.029999  135.199997  125.669998  132.070007  132.070007
# 2020-09-10  136.520004  138.389999  121.739998  124.430000  124.430000
# 2020-09-11  127.000000  128.190002  116.809998  121.709999  121.709999
# 2020-09-14  127.000000  130.809998  125.080002  127.980003  127.980003
# 2020-09-15  133.330002  135.130005  132.699997  134.850006  134.850006
#
#               Volume
# Date
# 2020-09-09  36294000
# 2020-09-10  58242100
# 2020-09-11  48224700
# 2020-09-14  33518800
# 2020-09-15   5726451

# %%
#def __init__(self,symbol,baseAmount,discountFactor,currentPrice,initialShares,model):

stockTrade=StockTrade('TQQQ',2000,0.1,104,30,model=model_1,realtrade=False)
for p in current_list:
    print('---------------------------------------------------------------------')
    print('current price is : {}'.format(p))
    stockTrade.tradeStock(p)
# Out:
# 2020-09-15 14:49:00,682,682 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,682,682 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,684,684 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,684,684 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,685,685 simulation_trading INFO buy 20 shares, amount 2000.0 at 100
# 2020-09-15 14:49:00,685,685 simulation_trading INFO buy 20 shares, amount 2000.0 at 100
# 2020-09-15 14:49:00,686,686 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,686,686 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,688,688 simulation_trading INFO sell 16 shares, amount 1800.0 at 111.11
# 2020-09-15 14:49:00,688,688 simulation_trading INFO sell 16 shares, amount 1800.0 at 111.11
# 2020-09-15 14:49:00,689,689 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,689,689 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,690,690 simulation_trading INFO before trade, current shares: 30
# 2020-09-15 14:49:00,690,690 simulation_trading INFO before trade, current shares: 30
# 2020-09-15 14:49:00,692,692 simulation_trading INFO now price 175.47999572753906, sold 16 shares at 111.11 worth 1800.0
# 2020-09-15 14:49:00,692,692 simulation_trading INFO now price 175.47999572753906, sold 16 shares at 111.11 worth 1800.0
# 2020-09-15 14:49:00,693,693 simulation_trading INFO after trade, current shares: 14
# 2020-09-15 14:49:00,693,693 simulation_trading INFO after trade, current shares: 14
# 2020-09-15 14:49:00,694,694 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,694,694 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,695,695 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,695,695 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,697,697 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,697,697 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,698,698 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,698,698 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,699,699 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,699,699 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,700,700 simulation_trading INFO {'price': 123.46, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,700,700 simulation_trading INFO {'price': 123.46, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,702,702 simulation_trading INFO {'price': 111.11, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,702,702 simulation_trading INFO {'price': 111.11, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,703,703 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,703,703 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,704,704 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,704,704 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,705,705 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,705,705 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,706,706 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,706,706 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,707,707 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,707,707 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,709,709 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,709,709 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,710,710 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,710,710 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,711,711 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,711,711 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,712,712 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,712,712 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,713,713 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,713,713 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,715,715 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,715,715 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,716,716 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,716,716 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,717,717 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,717,717 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,718,718 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,718,718 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,719,719 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,719,719 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,720,720 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,720,720 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,722,722 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,722,722 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,723,723 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,723,723 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,724,724 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,724,724 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,725,725 simulation_trading INFO buy 20 shares, amount 2000.0 at 100
# 2020-09-15 14:49:00,725,725 simulation_trading INFO buy 20 shares, amount 2000.0 at 100
# 2020-09-15 14:49:00,726,726 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,726,726 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,727,727 simulation_trading WARNING -------------
# 2020-09-15 14:49:00,727,727 simulation_trading WARNING -------------
# 2020-09-15 14:49:00,729,729 simulation_trading WARNING current share is 14, not enough shares in hand available for sale
# 2020-09-15 14:49:00,729,729 simulation_trading WARNING current share is 14, not enough shares in hand available for sale
# 2020-09-15 14:49:00,729,729 simulation_trading WARNING buy 22 shares at 175.47999572753906 before open the sell order
# 2020-09-15 14:49:00,729,729 simulation_trading WARNING buy 22 shares at 175.47999572753906 before open the sell order
# 2020-09-15 14:49:00,731,731 simulation_trading WARNING -------------
# 2020-09-15 14:49:00,731,731 simulation_trading WARNING -------------
# 2020-09-15 14:49:00,732,732 simulation_trading INFO sell 15 shares, amount 1800.0 at 123.46
# 2020-09-15 14:49:00,732,732 simulation_trading INFO sell 15 shares, amount 1800.0 at 123.46
# 2020-09-15 14:49:00,733,733 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,733,733 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,734,734 simulation_trading INFO before trade, current shares: 36
# 2020-09-15 14:49:00,734,734 simulation_trading INFO before trade, current shares: 36
# 2020-09-15 14:49:00,735,735 simulation_trading INFO now price 175.6699981689453, sold 15 shares at 123.46 worth 1800.0
# 2020-09-15 14:49:00,735,735 simulation_trading INFO now price 175.6699981689453, sold 15 shares at 123.46 worth 1800.0
# 2020-09-15 14:49:00,737,737 simulation_trading INFO after trade, current shares: 21
# 2020-09-15 14:49:00,737,737 simulation_trading INFO after trade, current shares: 21
# 2020-09-15 14:49:00,738,738 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,738,738 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,739,739 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,739,739 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,740,740 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,740,740 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,741,741 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,741,741 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,742,742 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,742,742 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,744,744 simulation_trading INFO {'price': 123.46, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,744,744 simulation_trading INFO {'price': 123.46, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,745,745 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,745,745 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,745,745 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,745,745 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,746,746 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,746,746 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,747,747 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,747,747 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,748,748 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,748,748 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,749,749 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,749,749 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,752,752 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,752,752 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,753,753 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,753,753 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,754,754 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,754,754 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,756,756 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,756,756 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,757,757 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,757,757 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,758,758 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,758,758 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,760,760 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,760,760 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,761,761 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,761,761 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,763,763 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,763,763 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,764,764 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,764,764 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,766,766 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,766,766 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,767,767 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,767,767 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,768,768 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,768,768 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,769,769 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,769,769 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,771,771 simulation_trading INFO buy 18 shares, amount 2000 at 111.11
# 2020-09-15 14:49:00,771,771 simulation_trading INFO buy 18 shares, amount 2000 at 111.11
# 2020-09-15 14:49:00,772,772 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,772,772 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,774,774 simulation_trading INFO sell 13 shares, amount 1800.0 at 137.17
# 2020-09-15 14:49:00,774,774 simulation_trading INFO sell 13 shares, amount 1800.0 at 137.17
# 2020-09-15 14:49:00,775,775 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,775,775 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,776,776 simulation_trading INFO before trade, current shares: 21
# 2020-09-15 14:49:00,776,776 simulation_trading INFO before trade, current shares: 21
# 2020-09-15 14:49:00,777,777 simulation_trading INFO now price 164.6699981689453, sold 13 shares at 137.17 worth 1800.0
# 2020-09-15 14:49:00,777,777 simulation_trading INFO now price 164.6699981689453, sold 13 shares at 137.17 worth 1800.0
# 2020-09-15 14:49:00,778,778 simulation_trading INFO after trade, current shares: 8
# 2020-09-15 14:49:00,778,778 simulation_trading INFO after trade, current shares: 8
# 2020-09-15 14:49:00,779,779 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,779,779 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,780,780 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,780,780 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,781,781 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,781,781 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,786,786 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,786,786 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,788,788 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,788,788 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,789,789 simulation_trading INFO {'price': 123.46, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,789,789 simulation_trading INFO {'price': 123.46, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,791,791 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,791,791 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,792,792 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,792,792 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,793,793 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,793,793 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,794,794 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,794,794 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,795,795 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,795,795 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,796,796 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,796,796 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,798,798 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,798,798 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,799,799 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,799,799 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,800,800 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,800,800 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,804,804 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,804,804 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,805,805 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,805,805 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,807,807 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,807,807 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,808,808 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,808,808 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,809,809 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,809,809 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,810,810 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,810,810 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,811,811 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,811,811 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,812,812 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,812,812 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,814,814 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,814,814 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,817,817 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,817,817 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,818,818 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,818,818 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,820,820 simulation_trading INFO buy 16 shares, amount 2000 at 123.46
# 2020-09-15 14:49:00,820,820 simulation_trading INFO buy 16 shares, amount 2000 at 123.46
# 2020-09-15 14:49:00,821,821 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,821,821 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,822,822 simulation_trading WARNING -------------
# 2020-09-15 14:49:00,822,822 simulation_trading WARNING -------------
# 2020-09-15 14:49:00,823,823 simulation_trading WARNING current share is 8, not enough shares in hand available for sale
# 2020-09-15 14:49:00,823,823 simulation_trading WARNING current share is 8, not enough shares in hand available for sale
# 2020-09-15 14:49:00,824,824 simulation_trading WARNING buy 24 shares at 164.6699981689453 before open the sell order
# 2020-09-15 14:49:00,824,824 simulation_trading WARNING buy 24 shares at 164.6699981689453 before open the sell order
# 2020-09-15 14:49:00,826,826 simulation_trading WARNING -------------
# 2020-09-15 14:49:00,826,826 simulation_trading WARNING -------------
# 2020-09-15 14:49:00,827,827 simulation_trading INFO sell 12 shares, amount 1800.0 at 152.42
# 2020-09-15 14:49:00,827,827 simulation_trading INFO sell 12 shares, amount 1800.0 at 152.42
# 2020-09-15 14:49:00,828,828 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,828,828 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,829,829 simulation_trading INFO before trade, current shares: 32
# 2020-09-15 14:49:00,829,829 simulation_trading INFO before trade, current shares: 32
# 2020-09-15 14:49:00,833,833 simulation_trading INFO now price 174.52999877929688, sold 12 shares at 152.42 worth 1800.0
# 2020-09-15 14:49:00,833,833 simulation_trading INFO now price 174.52999877929688, sold 12 shares at 152.42 worth 1800.0
# 2020-09-15 14:49:00,834,834 simulation_trading INFO after trade, current shares: 20
# 2020-09-15 14:49:00,834,834 simulation_trading INFO after trade, current shares: 20
# 2020-09-15 14:49:00,835,835 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,835,835 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,836,836 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,836,836 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,837,837 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,837,837 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,838,838 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,838,838 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,839,839 simulation_trading INFO {'price': 137.17, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,839,839 simulation_trading INFO {'price': 137.17, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,843,843 simulation_trading INFO {'price': 123.46, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,843,843 simulation_trading INFO {'price': 123.46, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,844,844 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,844,844 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,845,845 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,845,845 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,846,846 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,846,846 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,847,847 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,847,847 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,848,848 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,848,848 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,850,850 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,850,850 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,851,851 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,851,851 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,852,852 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,852,852 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,853,853 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,853,853 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,854,854 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,854,854 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,855,855 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,855,855 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,856,856 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,856,856 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,857,857 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,857,857 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,863,863 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,863,863 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,864,864 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,864,864 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,865,865 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,865,865 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,867,867 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,867,867 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,868,868 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,868,868 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,870,870 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,870,870 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,872,872 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,872,872 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,873,873 simulation_trading INFO buy 15 shares, amount 2000 at 137.17
# 2020-09-15 14:49:00,873,873 simulation_trading INFO buy 15 shares, amount 2000 at 137.17
# 2020-09-15 14:49:00,874,874 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,874,874 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,875,875 simulation_trading INFO sell 11 shares, amount 1800.0 at 169.35
# 2020-09-15 14:49:00,875,875 simulation_trading INFO sell 11 shares, amount 1800.0 at 169.35
# 2020-09-15 14:49:00,877,877 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,877,877 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,880,880 simulation_trading INFO before trade, current shares: 20
# 2020-09-15 14:49:00,880,880 simulation_trading INFO before trade, current shares: 20
# 2020-09-15 14:49:00,881,881 simulation_trading INFO now price 123.86000061035156, bought 15 shares at 137.17 worth 2000
# 2020-09-15 14:49:00,881,881 simulation_trading INFO now price 123.86000061035156, bought 15 shares at 137.17 worth 2000
# 2020-09-15 14:49:00,882,882 simulation_trading INFO money required 5748.279862060546
# 2020-09-15 14:49:00,882,882 simulation_trading INFO money required 5748.279862060546
# 2020-09-15 14:49:00,882,882 simulation_trading INFO after trade, current shares: 35
# initialize, bought 30 shares at 104 worth 3120
# ---------------------------------------------------------------------
# current price is : 175.47999572753906
# ---------------------------------------------------------------------
# current price is : 175.6699981689453
# ---------------------------------------------------------------------
# current price is : 164.6699981689453
# ---------------------------------------------------------------------
# current price is : 174.52999877929688
# ---------------------------------------------------------------------
# current price is : 166.72999572753906
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 167.39999389648438
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 142.82000732421875
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 147.72999572753906
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 145.3800048828125
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 150.3000030517578
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 123.86000061035156
# 2020-09-15 14:49:00,882,882 simulation_trading INFO after trade, current shares: 35
# 2020-09-15 14:49:00,883,883 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,883,883 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,884,884 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,884,884 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,885,885 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,885,885 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,886,886 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,886,886 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,887,887 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,887,887 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,888,888 simulation_trading INFO {'price': 123.46, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,888,888 simulation_trading INFO {'price': 123.46, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,889,889 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,889,889 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,890,890 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,890,890 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,893,893 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,893,893 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:00,895,895 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,895,895 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:00,896,896 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,896,896 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:00,897,897 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,897,897 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:00,898,898 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,898,898 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,899,899 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,899,899 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,901,901 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,901,901 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,902,902 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,902,902 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,903,903 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,903,903 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,905,905 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,905,905 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,906,906 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,906,906 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,907,907 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,907,907 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,909,909 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,909,909 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,910,910 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,910,910 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:00,911,911 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,911,911 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:00,912,912 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,912,912 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:00,913,913 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,913,913 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:00,915,915 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,915,915 simulation_trading INFO buy setting:
# 2020-09-15 14:49:00,916,916 simulation_trading INFO buy 16 shares, amount 2000 at 123.46
# 2020-09-15 14:49:00,916,916 simulation_trading INFO buy 16 shares, amount 2000 at 123.46
# 2020-09-15 14:49:00,917,917 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,917,917 simulation_trading INFO sell setting:
# 2020-09-15 14:49:00,918,918 simulation_trading INFO sell 12 shares, amount 1800.0 at 152.42
# 2020-09-15 14:49:00,918,918 simulation_trading INFO sell 12 shares, amount 1800.0 at 152.42
# 2020-09-15 14:49:00,920,920 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,920,920 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:00,922,922 simulation_trading INFO before trade, current shares: 35
# 2020-09-15 14:49:00,922,922 simulation_trading INFO before trade, current shares: 35
# 2020-09-15 14:49:00,923,923 simulation_trading INFO now price 121.05999755859375, bought 16 shares at 123.46 worth 2000
# 2020-09-15 14:49:00,923,923 simulation_trading INFO now price 121.05999755859375, bought 16 shares at 123.46 worth 2000
# 2020-09-15 14:49:00,924,924 simulation_trading INFO money required 7723.639862060547
# 2020-09-15 14:49:00,924,924 simulation_trading INFO money required 7723.639862060547
# 2020-09-15 14:49:00,926,926 simulation_trading INFO after trade, current shares: 51
# 2020-09-15 14:49:00,926,926 simulation_trading INFO after trade, current shares: 51
# 2020-09-15 14:49:00,927,927 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,927,927 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,928,928 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,928,928 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,929,929 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,929,929 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,930,930 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,930,930 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,932,932 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:00,932,932 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# ...
# 2020-09-15 14:49:00,985,985 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,985,985 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:00,986,986 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,986,986 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:00,987,987 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,987,987 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:00,988,988 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,988,988 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:00,990,990 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,990,990 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:00,993,993 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,993,993 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:00,995,995 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,995,995 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:00,997,997 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,997,997 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:00,998,998 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:00,998,998 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:01,000,0 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:01,000,0 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:01,001,1 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:01,001,1 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:01,003,3 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:01,003,3 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:01,004,4 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:01,004,4 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:01,005,5 simulation_trading INFO buy setting:
# 2020-09-15 14:49:01,005,5 simulation_trading INFO buy setting:
# 2020-09-15 14:49:01,007,7 simulation_trading INFO buy 16 shares, amount 2000 at 123.46
# 2020-09-15 14:49:01,007,7 simulation_trading INFO buy 16 shares, amount 2000 at 123.46
# 2020-09-15 14:49:01,009,9 simulation_trading INFO sell setting:
# 2020-09-15 14:49:01,009,9 simulation_trading INFO sell setting:
# 2020-09-15 14:49:01,010,10 simulation_trading INFO sell 12 shares, amount 1800.0 at 152.42
# 2020-09-15 14:49:01,010,10 simulation_trading INFO sell 12 shares, amount 1800.0 at 152.42
# 2020-09-15 14:49:01,011,11 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:01,011,11 simulation_trading INFO ---------execute order--------
# 2020-09-15 14:49:01,012,12 simulation_trading INFO before trade, current shares: 38
# 2020-09-15 14:49:01,012,12 simulation_trading INFO before trade, current shares: 38
# 2020-09-15 14:49:01,013,13 simulation_trading INFO now price 121.73999786376953, bought 16 shares at 123.46 worth 2000
# 2020-09-15 14:49:01,013,13 simulation_trading INFO now price 121.73999786376953, bought 16 shares at 123.46 worth 2000
# 2020-09-15 14:49:01,016,16 simulation_trading INFO money required 7915.789862060548
# 2020-09-15 14:49:01,016,16 simulation_trading INFO money required 7915.789862060548
# 2020-09-15 14:49:01,018,18 simulation_trading INFO after trade, current shares: 54
# 2020-09-15 14:49:01,018,18 simulation_trading INFO after trade, current shares: 54
# 2020-09-15 14:49:01,019,19 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,019,19 simulation_trading INFO {'price': 209.08, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,020,20 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,020,20 simulation_trading INFO {'price': 188.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,021,21 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,021,21 simulation_trading INFO {'price': 169.35, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,022,22 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,022,22 simulation_trading INFO {'price': 152.42, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,023,23 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,023,23 simulation_trading INFO {'price': 137.17, 'buy': False, 'buy_amount': 2000, 'sell': True, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,024,24 simulation_trading INFO {'price': 123.46, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,024,24 simulation_trading INFO {'price': 123.46, 'buy': False, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,025,25 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,025,25 simulation_trading INFO {'price': 111.11, 'buy': True, 'buy_amount': 2000, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,026,26 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,026,26 simulation_trading INFO {'price': 100, 'buy': True, 'buy_amount': 2000.0, 'sell': False, 'sell_amount': 1800.0}
# 2020-09-15 14:49:01,027,27 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:01,027,27 simulation_trading INFO {'price': 90.0, 'buy': True, 'buy_amount': 2200.0, 'sell': False, 'sell_amount': 1920.0}
# 2020-09-15 14:49:01,029,29 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:01,029,29 simulation_trading INFO {'price': 81.0, 'buy': True, 'buy_amount': 2380.0, 'sell': False, 'sell_amount': 2020.0}
# 2020-09-15 14:49:01,030,30 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:01,030,30 simulation_trading INFO {'price': 72.9, 'buy': True, 'buy_amount': 2540.0, 'sell': False, 'sell_amount': 2120.0}
# 2020-09-15 14:49:01,033,33 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:01,033,33 simulation_trading INFO {'price': 65.61, 'buy': True, 'buy_amount': 2680.0, 'sell': False, 'sell_amount': 2220.0}
# 2020-09-15 14:49:01,034,34 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:01,034,34 simulation_trading INFO {'price': 59.05, 'buy': True, 'buy_amount': 2820.0, 'sell': False, 'sell_amount': 2300.0}
# 2020-09-15 14:49:01,035,35 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:01,035,35 simulation_trading INFO {'price': 53.14, 'buy': True, 'buy_amount': 2940.0, 'sell': False, 'sell_amount': 2360.0}
# 2020-09-15 14:49:01,036,36 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:01,036,36 simulation_trading INFO {'price': 47.83, 'buy': True, 'buy_amount': 3040.0, 'sell': False, 'sell_amount': 2420.0}
# 2020-09-15 14:49:01,037,37 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:01,037,37 simulation_trading INFO {'price': 43.05, 'buy': True, 'buy_amount': 3140.0, 'sell': False, 'sell_amount': 2480.0}
# 2020-09-15 14:49:01,038,38 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:01,038,38 simulation_trading INFO {'price': 38.74, 'buy': True, 'buy_amount': 3220.0, 'sell': False, 'sell_amount': 2540.0}
# 2020-09-15 14:49:01,039,39 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:01,039,39 simulation_trading INFO {'price': 34.87, 'buy': True, 'buy_amount': 3300.0, 'sell': False, 'sell_amount': 2580.0}
# 2020-09-15 14:49:01,040,40 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:01,040,40 simulation_trading INFO {'price': 31.38, 'buy': True, 'buy_amount': 3380.0, 'sell': False, 'sell_amount': 2620.0}
# 2020-09-15 14:49:01,041,41 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:01,041,41 simulation_trading INFO {'price': 28.24, 'buy': True, 'buy_amount': 3440.0, 'sell': False, 'sell_amount': 2660.0}
# 2020-09-15 14:49:01,043,43 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:01,043,43 simulation_trading INFO {'price': 25.42, 'buy': True, 'buy_amount': 3500.0, 'sell': False, 'sell_amount': 2700.0}
# 2020-09-15 14:49:01,044,44 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:01,044,44 simulation_trading INFO {'price': 22.88, 'buy': True, 'buy_amount': 3540.0, 'sell': False, 'sell_amount': 2720.0}
# 2020-09-15 14:49:01,046,46 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:01,046,46 simulation_trading INFO {'price': 20.59, 'buy': True, 'buy_amount': 3580.0, 'sell': False, 'sell_amount': 2760.0}
# 2020-09-15 14:49:01,047,47 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:01,047,47 simulation_trading INFO {'price': 18.53, 'buy': True, 'buy_amount': 3620.0, 'sell': False, 'sell_amount': 2780.0}
# 2020-09-15 14:49:01,048,48 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:01,048,48 simulation_trading INFO ---------set up open orders-----------
# 2020-09-15 14:49:01,049,49 simulation_trading INFO buy setting:
# 2020-09-15 14:49:01,049,49 simulation_trading INFO buy setting:
# 2020-09-15 14:49:01,050,50 simulation_trading INFO buy 18 shares, amount 2000 at 111.11
# 2020-09-15 14:49:01,050,50 simulation_trading INFO buy 18 shares, amount 2000 at 111.11
# 2020-09-15 14:49:01,051,51 simulation_trading INFO sell setting:
# 2020-09-15 14:49:01,051,51 simulation_trading INFO sell setting:
# 2020-09-15 14:49:01,052,52 simulation_trading INFO sell 13 shares, amount 1800.0 at 137.17
# 2020-09-15 14:49:01,052,52 simulation_trading INFO sell 13 shares, amount 1800.0 at 137.17
# ---------------------------------------------------------------------
# current price is : 141.63999938964844
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 124.94999694824219
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 133.97000122070312
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 121.05999755859375
# ---------------------------------------------------------------------
# current price is : 121.62000274658203
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 129.02999877929688
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 135.1999969482422
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 125.66999816894531
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 132.07000732421875
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 136.52000427246094
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 138.38999938964844
# ---------------------------------------------------------------------
# current price is : 121.73999786376953
# ---------------------------------------------------------------------
# current price is : 124.43000030517578
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 127.0
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 128.19000244140625
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 116.80999755859375
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 121.70999908447266
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 127.0
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 130.80999755859375
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 125.08000183105469
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 127.9800033569336
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 133.3300018310547
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 135.1300048828125
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 132.6999969482422
# ---------no execute --------
# ---------------------------------------------------------------------
# current price is : 134.85000610351562
# ---------no execute --------

# %%
# check the open orders
stockTrade.openOrders
# Out:
# {'buy': [{'shares': 18, 'amount': 2000, 'price': 111.11, 'position': 6}],
#  'sell': [{'shares': 13, 'amount': 1800.0, 'price': 137.17, 'position': 4}]}

# %%
# define a function to send orders to robinhood
def send_orders_to_rb():
    r.orders.cancel_all_stock_orders() # clean all orders
    open_orders=stockTrade.openOrders
    limit_put_args={'symbol':'TQQQ','quantity':open_orders['buy'][0]['shares'],'limitPrice':open_orders['buy'][0]['price'],'extendedHours':True}
    r.orders.order_buy_limit(**limit_put_args)  # make the limit buy order 
    limit_sell_args={'symbol':'TQQQ','quantity':open_orders['sell'][0]['shares'],'limitPrice':open_orders['sell'][0]['price'],'extendedHours':True}
    r.orders.order_sell_limit(**limit_sell_args)# make the limit sell order
    print('---confirm the orders---')
    r.orders.get_all_open_stock_orders() # check the orders

# %%
#send_orders_to_rb()

# %% [markdown]
# ## Simulate the trading by testing with different values for parameters

# %%
"""
different factors to test: year, discount factor, 
"""
from datetime import date
def get_history_data(years): # years is a list of year, such [2017,2018,2019]
    data_years=dict()
    for year in years:    
        df=yf.download('TQQQ',start=date(year,1,1),end=date(year+1,1,1))
        data_years[year]=df
    return data_years  

#__init__(self,symbol,baseAmount,discountFactor,currentPrice,initialShares)
def test_year_discount_model(year,discount,model):
    df=yf.download('TQQQ',start=date(year,1,1),end=date(year+1,1,1))
    data_list=convert_df_to_list(df)
    start_price,end_price=data_list[0],data_list[-1]
    baseAmount=2000
    discountFactor=discount
    currentPrice=start_price
    initialShares=round(2*2000/currentPrice)
    stockTrade=StockTrade('TQQQ',baseAmount,discountFactor,currentPrice,initialShares,model=model)
    for price in data_list:
        print('current price is ', price)
        stockTrade.currentPrice=price
        stockTrade.tradeStock(price)
    return stockTrade

def check_results(stockTrade):
    print('profit: ',stockTrade.get_profit(stockTrade.currentPrice))
    print('openshare: ', stockTrade.openShares)
    print('openorders: ',stockTrade.openOrders)
    print('total money spent on buy: ',stockTrade.totalMoneyBuy)
    print('total money from sell : ', stockTrade.totalmoneySell)
    print('max money needed', stockTrade.max_money_needed)
    print('max loss', stockTrade.max_loss)
    return

# %%
logger.removeHandler(stream_handler) # don't print on console
import numpy as np
import itertools
years=[2018,2019,2020]
discount_factors=list(range(2,21,4))
models=[model_1,model_2]
iterations=itertools.product(years,discount_factors,models)
stockTrades=dict()
df_years=get_history_data(years)
for it in iterations:
    year,discount,model=it
    name='{}-{}-{}'.format(year,discount,model.__name__)
    stockTrades[name]=test_year_discount_model(year,discount/100,model)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# initialize, bought 85 shares at 46.96666717529297 worth 3992.1667098999023
# current price is  46.96666717529297
# ---------no execute --------
# current price is  48.71333312988281
# current price is  46.630001068115234
# ---------no execute --------
# current price is  48.61333465576172
# current price is  48.810001373291016
# ---------no execute --------
# current price is  50.220001220703125
# current price is  48.8033332824707
# ---------no execute --------
# current price is  50.03666687011719
# ---------no execute --------
# current price is  50.62333297729492
# current price is  50.8033332824707
# ---------no execute --------
# current price is  50.1533317565918
# ---------no execute --------
# current price is  50.33000183105469
# ---------no execute --------
# current price is  51.03333282470703
# ---------no execute --------
# current price is  51.959999084472656
# current price is  50.77000045776367
# ---------no execute --------
# current price is  51.849998474121094
# ---------no execute --------
# current price is  51.84333419799805
# ---------no execute --------
# current price is  52.53333282470703
# current price is  51.7933349609375
# ---------no execute --------
# current price is  52.426666259765625
# ---------no execute --------
# current price is  52.746665954589844
# ---------no execute --------
# current price is  52.92333221435547
# ---------no execute --------
# current price is  52.0
# ---------no execute --------
# current price is  52.46666717529297
# ---------no execute --------
# current price is  51.73666763305664
# ---------no execute --------
# current price is  52.11333465576172
# ---------no execute --------
# current price is  51.06999969482422
# current price is  52.09333419799805
# ---------no execute --------
# current price is  52.356666564941406
# ---------no execute --------
# current price is  53.13666534423828
# current price is  52.11333465576172
# ---------no execute --------
# current price is  53.13666534423828
# ---------no execute --------
# current price is  52.9566650390625
# ---------no execute --------
# current price is  54.470001220703125
# current price is  52.80666732788086
# ---------no execute --------
# current price is  54.26333236694336
# ---------no execute --------
# current price is  55.36000061035156
# current price is  56.223331451416016
# current price is  53.36000061035156
# current price is  53.84333419799805
# ---------no execute --------
# current price is  54.560001373291016
# ---------no execute --------
# current price is  55.81666564941406
# current price is  53.823333740234375
# current price is  55.540000915527344
# ---------no execute --------
# current price is  55.29666519165039
# ---------no execute --------
# current price is  55.96333312988281
# current price is  54.9033317565918
# ---------no execute --------
# current price is  55.59333419799805
# ---------no execute --------
# current price is  56.06999969482422
# ---------no execute --------
# current price is  56.36666488647461
# ---------no execute --------
# current price is  55.28333282470703
# ---------no execute --------
# current price is  56.12666702270508
# ---------no execute --------
# current price is  55.99333190917969
# ---------no execute --------
# current price is  57.880001068115234
# current price is  55.849998474121094
# ---------no execute --------
# current price is  57.880001068115234
# ---------no execute --------
# current price is  58.436668395996094
# current price is  59.4900016784668
# current price is  58.3466682434082
# ---------no execute --------
# current price is  59.3466682434082
# ---------no execute --------
# current price is  59.66999816894531
# ---------no execute --------
# current price is  60.086666107177734
# ---------no execute --------
# current price is  57.150001525878906
# current price is  58.143333435058594
# ---------no execute --------
# current price is  59.356666564941406
# current price is  59.400001525878906
# ---------no execute --------
# current price is  57.52333450317383
# current price is  58.06999969482422
# ---------no execute --------
# current price is  59.0
# ---------no execute --------
# current price is  60.663333892822266
# current price is  58.69333267211914
# ---------no execute --------
# current price is  60.663333892822266
# current price is  60.3033332824707
# ---------no execute --------
# current price is  60.71333312988281
# ---------no execute --------
# current price is  59.470001220703125
# ---------no execute --------
# current price is  59.86000061035156
# ---------no execute --------
# current price is  58.19333267211914
# current price is  59.11666488647461
# ---------no execute --------
# current price is  57.426666259765625
# current price is  58.33000183105469
# ---------no execute --------
# current price is  59.349998474121094
# current price is  59.686668395996094
# ---------no execute --------
# current price is  58.0
# ---------no execute --------
# current price is  59.04999923706055
# ---------no execute --------
# current price is  57.74333190917969
# current price is  59.400001525878906
# current price is  56.959999084472656
# current price is  57.573333740234375
# ---------no execute --------
# current price is  56.93000030517578
# ---------no execute --------
# current price is  57.276668548583984
# ---------no execute --------
# current price is  53.970001220703125
# current price is  54.05666732788086
# current price is  52.58333206176758
# current price is  55.21333312988281
# ---------no execute --------
# current price is  47.53666687011719
# current price is  47.81666564941406
# current price is  45.606666564941406
# current price is  51.66666793823242
# ---------no execute --------
# current price is  45.0099983215332
# current price is  51.503334045410156
# current price is  51.02000045776367
# ---------no execute --------
# current price is  52.663333892822266
# current price is  49.46666717529297
# current price is  49.46666717529297
# current price is  49.97666549682617
# ---------no execute --------
# current price is  50.04666519165039
# ---------no execute --------
# current price is  43.33333206176758
# current price is  43.336666107177734
# current price is  45.06666564941406
# current price is  46.38333511352539
# current price is  40.400001525878906
# current price is  45.37666702270508
# ---------no execute --------
# current price is  46.926666259765625
# current price is  48.79666519165039
# current price is  45.74333190917969
# current price is  47.91666793823242
# current price is  47.07666778564453
# ---------no execute --------
# current price is  48.86666488647461
# current price is  46.790000915527344
# current price is  48.5
# current price is  47.77333450317383
# ---------no execute --------
# current price is  51.540000915527344
# current price is  47.723331451416016
# current price is  51.34000015258789
# current price is  52.66666793823242
# current price is  54.09333419799805
# current price is  51.060001373291016
# ---------no execute --------
# current price is  54.02333450317383
# current price is  53.630001068115234
# current price is  55.15666580200195
# current price is  53.11666488647461
# current price is  53.41999816894531
# ---------no execute --------
# current price is  52.80666732788086
# ---------no execute --------
# current price is  55.08000183105469
# current price is  52.75666809082031
# current price is  53.686668395996094
# ---------no execute --------
# current price is  54.4566650390625
# ---------no execute --------
# current price is  56.06999969482422
# current price is  53.16666793823242
# current price is  53.20333480834961
# ---------no execute --------
# current price is  53.97666549682617
# ---------no execute --------
# current price is  54.78333282470703
# current price is  52.80666732788086
# current price is  53.21333312988281
# ---------no execute --------
# current price is  54.41999816894531
# ---------no execute --------
# current price is  56.41999816894531
# current price is  53.8466682434082
# ---------no execute --------
# current price is  56.38333511352539
# current price is  57.27000045776367
# current price is  58.67333221435547
# current price is  57.14666748046875
# ---------no execute --------
# current price is  58.64666748046875
# ---------no execute --------
# current price is  58.75
# ---------no execute --------
# current price is  59.063331604003906
# ---------no execute --------
# current price is  56.473331451416016
# current price is  56.54666519165039
# ---------no execute --------
# current price is  57.4900016784668
# ---------no execute --------
# current price is  58.04999923706055
# current price is  55.35333251953125
# current price is  55.40999984741211
# current price is  55.53333282470703
# ---------no execute --------
# current price is  56.27333450317383
# ---------no execute --------
# current price is  51.22666549682617
# current price is  52.74333190917969
# current price is  50.893333435058594
# current price is  54.4466667175293
# current price is  50.2599983215332
# current price is  54.19333267211914
# current price is  53.43000030517578
# ---------no execute --------
# current price is  56.37333297729492
# current price is  52.78666687011719
# current price is  55.893333435058594
# current price is  56.72666549682617
# current price is  57.22999954223633
# current price is  55.599998474121094
# current price is  56.599998474121094
# ---------no execute --------
# current price is  55.36333465576172
# ---------no execute --------
# current price is  57.16666793823242
# current price is  55.073333740234375
# current price is  57.02333450317383
# current price is  57.65999984741211
# ---------no execute --------
# current price is  58.073333740234375
# current price is  57.03666687011719
# ---------no execute --------
# current price is  57.87333297729492
# ---------no execute --------
# current price is  59.186668395996094
# current price is  61.24333190917969
# current price is  58.926666259765625
# current price is  61.24333190917969
# current price is  61.83333206176758
# current price is  62.723331451416016
# ---------no execute --------
# current price is  61.4466667175293
# ---------no execute --------
# current price is  62.15999984741211
# ---------no execute --------
# current price is  61.83333206176758
# ---------no execute --------
# current price is  62.723331451416016
# ---------no execute --------
# current price is  59.28666687011719
# current price is  59.9033317565918
# ---------no execute --------
# current price is  60.65999984741211
# ---------no execute --------
# current price is  60.84333419799805
# ---------no execute --------
# current price is  58.93333435058594
# current price is  59.70000076293945
# ---------no execute --------
# current price is  59.880001068115234
# ---------no execute --------
# current price is  60.60333251953125
# current price is  58.880001068115234
# current price is  59.43333435058594
# ---------no execute --------
# current price is  59.77333450317383
# ---------no execute --------
# current price is  60.22666549682617
# ---------no execute --------
# current price is  58.93333435058594
# ---------no execute --------
# current price is  59.040000915527344
# ---------no execute --------
# current price is  57.496665954589844
# current price is  57.496665954589844
# ---------no execute --------
# current price is  53.689998626708984
# current price is  55.33333206176758
# current price is  55.3466682434082
# ---------no execute --------
# current price is  56.13333511352539
# ---------no execute --------
# current price is  54.723331451416016
# ---------no execute --------
# current price is  55.7400016784668
# ---------no execute --------
# current price is  55.33333206176758
# ---------no execute --------
# current price is  56.86666488647461
# current price is  54.246665954589844
# current price is  54.93333435058594
# ---------no execute --------
# current price is  52.79999923706055
# current price is  53.86666488647461
# ---------no execute --------
# current price is  50.733333587646484
# current price is  50.91999816894531
# current price is  50.733333587646484
# current price is  51.16666793823242
# ---------no execute --------
# current price is  46.80666732788086
# current price is  46.80666732788086
# current price is  49.66666793823242
# ---------no execute --------
# current price is  52.279998779296875
# current price is  47.459999084472656
# current price is  52.073333740234375
# current price is  53.29666519165039
# current price is  53.29666519165039
# current price is  45.723331451416016
# current price is  47.08000183105469
# current price is  46.25666809082031
# current price is  47.606666564941406
# current price is  44.33333206176758
# current price is  45.4566650390625
# current price is  46.14666748046875
# ---------no execute --------
# current price is  49.233333587646484
# current price is  44.84333419799805
# current price is  47.973331451416016
# current price is  46.84000015258789
# ---------no execute --------
# current price is  47.5
# ---------no execute --------
# current price is  42.25666809082031
# current price is  43.71333312988281
# current price is  44.91666793823242
# ---------no execute --------
# current price is  45.733333587646484
# ---------no execute --------
# current price is  42.79666519165039
# current price is  45.18000030517578
# ---------no execute --------
# current price is  42.5433349609375
# current price is  47.72666549682617
# current price is  42.400001525878906
# current price is  47.31666564941406
# current price is  48.72666549682617
# current price is  48.91666793823242
# current price is  47.0533332824707
# ---------no execute --------
# current price is  48.060001373291016
# current price is  46.563331604003906
# ---------no execute --------
# current price is  47.939998626708984
# ---------no execute --------
# current price is  43.80666732788086
# current price is  44.473331451416016
# current price is  45.64666748046875
# ---------no execute --------
# current price is  48.086666107177734
# current price is  45.18333435058594
# current price is  45.36333465576172
# ---------no execute --------
# current price is  47.483333587646484
# current price is  48.849998474121094
# current price is  46.54666519165039
# ---------no execute --------
# current price is  48.36000061035156
# current price is  47.53333282470703
# ---------no execute --------
# current price is  49.12333297729492
# ---------no execute --------
# current price is  47.4033317565918
# ---------no execute --------
# current price is  47.54666519165039
# ---------no execute --------
# current price is  48.5
# ---------no execute --------
# current price is  49.75
# current price is  48.33000183105469
# ---------no execute --------
# current price is  49.21333312988281
# ---------no execute --------
# current price is  50.003334045410156
# ---------no execute --------
# current price is  50.21333312988281
# ---------no execute --------
# current price is  47.88666534423828
# current price is  48.483333587646484
# ---------no execute --------
# current price is  49.473331451416016
# current price is  50.130001068115234
# ---------no execute --------
# current price is  48.59333419799805
# ---------no execute --------
# current price is  49.5533332824707
# ---------no execute --------
# current price is  51.040000915527344
# current price is  53.106666564941406
# current price is  50.78333282470703
# ---------no execute --------
# current price is  52.723331451416016
# current price is  52.79999923706055
# ---------no execute --------
# current price is  53.650001525878906
# current price is  52.03333282470703
# current price is  53.09000015258789
# ---------no execute --------
# current price is  52.323333740234375
# ---------no execute --------
# current price is  52.65999984741211
# ---------no execute --------
# current price is  51.08333206176758
# current price is  51.64666748046875
# ---------no execute --------
# current price is  51.25
# ---------no execute --------
# current price is  51.33333206176758
# ---------no execute --------
# current price is  48.63333511352539
# current price is  49.16999816894531
# current price is  49.85333251953125
# ---------no execute --------
# current price is  50.439998626708984
# current price is  48.0
# current price is  48.78333282470703
# ---------no execute --------
# current price is  49.426666259765625
# ---------no execute --------
# current price is  49.6966667175293
# ---------no execute --------
# current price is  44.720001220703125
# current price is  45.67333221435547
# current price is  45.893333435058594
# current price is  46.400001525878906
# ---------no execute --------
# current price is  43.959999084472656
# current price is  45.85333251953125
# ---------no execute --------
# current price is  47.5966682434082
# current price is  49.16666793823242
# current price is  47.13999938964844
# ---------no execute --------
# current price is  48.6966667175293
# current price is  50.82666778564453
# current price is  50.88333511352539
# current price is  47.973331451416016
# current price is  48.810001373291016
# ---------no execute --------
# current price is  49.13666534423828
# ---------no execute --------
# current price is  50.03333282470703
# ---------no execute --------
# current price is  47.37666702270508
# current price is  47.77000045776367
# ---------no execute --------
# current price is  47.35333251953125
# ---------no execute --------
# current price is  49.38666534423828
# current price is  47.0433349609375
# current price is  49.323333740234375
# current price is  49.650001525878906
# ---------no execute --------
# current price is  50.08333206176758
# ---------no execute --------
# current price is  48.33333206176758
# ---------no execute --------
# current price is  48.46333312988281
# ---------no execute --------
# current price is  47.81666564941406
# current price is  48.996665954589844
# ---------no execute --------
# current price is  46.150001525878906
# current price is  48.46666717529297
# current price is  47.85333251953125
# ---------no execute --------
# current price is  51.54999923706055
# current price is  47.72666549682617
# current price is  51.19333267211914
# current price is  51.95333480834961
# current price is  52.97666549682617
# current price is  51.7933349609375
# ---------no execute --------
# current price is  52.40999984741211
# current price is  52.130001068115234
# ---------no execute --------
# current price is  52.64666748046875
# ---------no execute --------
# current price is  51.16999816894531
# current price is  52.23666763305664
# ---------no execute --------
# current price is  52.599998474121094
# current price is  54.11666488647461
# current price is  52.03333282470703
# current price is  53.98666763305664
# current price is  54.5
# ---------no execute --------
# current price is  55.779998779296875
# current price is  54.380001068115234
# ---------no execute --------
# current price is  55.66666793823242
# current price is  55.38333511352539
# ---------no execute --------
# current price is  55.87333297729492
# ---------no execute --------
# current price is  54.766666412353516
# ---------no execute --------
# current price is  55.5
# ---------no execute --------
# current price is  55.849998474121094
# ---------no execute --------
# current price is  56.83000183105469
# current price is  55.5
# current price is  55.746665954589844
# ---------no execute --------
# current price is  54.41999816894531
# current price is  54.51333236694336
# ---------no execute --------
# current price is  53.04666519165039
# current price is  53.94333267211914
# ---------no execute --------
# current price is  54.06666564941406
# ---------no execute --------
# current price is  55.33333206176758
# current price is  54.0533332824707
# ---------no execute --------
# current price is  54.936668395996094
# ---------no execute --------
# current price is  54.37666702270508
# ---------no execute --------
# current price is  55.563331604003906
# ---------no execute --------
# current price is  53.5099983215332
# ---------no execute --------
# current price is  54.31666564941406
# ---------no execute --------
# current price is  53.6966667175293
# ---------no execute --------
# current price is  54.233333587646484
# ---------no execute --------
# current price is  53.22666549682617
# current price is  53.4466667175293
# ---------no execute --------
# current price is  54.67333221435547
# current price is  55.40999984741211
# ---------no execute --------
# current price is  53.66666793823242
# ---------no execute --------
# current price is  54.380001068115234
# ---------no execute --------
# current price is  55.07666778564453
# ---------no execute --------
# current price is  55.36666488647461
# ---------no execute --------
# current price is  53.86000061035156
# ---------no execute --------
# current price is  54.0966682434082
# ---------no execute --------
# current price is  52.900001525878906
# current price is  55.4900016784668
# current price is  52.8466682434082
# current price is  55.4566650390625
# current price is  55.439998626708984
# ---------no execute --------
# current price is  55.709999084472656
# current price is  53.7400016784668
# current price is  55.40999984741211
# ---------no execute --------
# current price is  55.43000030517578
# ---------no execute --------
# current price is  56.15999984741211
# current price is  55.06999969482422
# ---------no execute --------
# current price is  55.54999923706055
# ---------no execute --------
# current price is  54.790000915527344
# ---------no execute --------
# current price is  55.779998779296875
# ---------no execute --------
# current price is  53.83000183105469
# current price is  54.84000015258789
# ---------no execute --------
# current price is  55.400001525878906
# ---------no execute --------
# current price is  56.279998779296875
# current price is  55.04999923706055
# ---------no execute --------
# current price is  56.0099983215332
# ---------no execute --------
# current price is  55.93000030517578
# ---------no execute --------
# current price is  56.97999954223633
# current price is  55.439998626708984
# current price is  55.88999938964844
# ---------no execute --------
# current price is  56.650001525878906
# ---------no execute --------
# current price is  58.58000183105469
# current price is  56.650001525878906
# ---------no execute --------
# current price is  58.4900016784668
# current price is  58.900001525878906
# ---------no execute --------
# current price is  60.099998474121094
# current price is  58.81999969482422
# ---------no execute --------
# current price is  59.9900016784668
# ---------no execute --------
# current price is  60.470001220703125
# current price is  60.90999984741211
# ---------no execute --------
# current price is  59.810001373291016
# ---------no execute --------
# current price is  60.61000061035156
# ---------no execute --------
# current price is  60.79999923706055
# ---------no execute --------
# current price is  61.65999984741211
# current price is  59.880001068115234
# current price is  61.61000061035156
# current price is  61.689998626708984
# ---------no execute --------
# current price is  61.720001220703125
# ---------no execute --------
# current price is  59.22999954223633
# current price is  60.18000030517578
# ---------no execute --------
# current price is  59.22999954223633
# ---------no execute --------
# current price is  60.400001525878906
# ---------no execute --------
# current price is  58.83000183105469
# current price is  60.13999938964844
# ---------no execute --------
# current price is  59.9900016784668
# ---------no execute --------
# current price is  61.060001373291016
# current price is  59.959999084472656
# ---------no execute --------
# current price is  60.61000061035156
# ---------no execute --------
# current price is  60.86000061035156
# ---------no execute --------
# current price is  61.72999954223633
# current price is  60.66999816894531
# ---------no execute --------
# current price is  61.56999969482422
# ---------no execute --------
# current price is  61.79999923706055
# ---------no execute --------
# current price is  62.93000030517578
# current price is  61.13999938964844
# current price is  61.5
# ---------no execute --------
# current price is  62.380001068115234
# ---------no execute --------
# current price is  63.65999984741211
# current price is  62.209999084472656
# ---------no execute --------
# current price is  63.369998931884766
# ---------no execute --------
# current price is  62.63999938964844
# ---------no execute --------
# current price is  63.09000015258789
# ---------no execute --------
# current price is  61.79999923706055
# ---------no execute --------
# current price is  62.7400016784668
# ---------no execute --------
# current price is  61.5
# current price is  62.75
# ---------no execute --------
# current price is  60.91999816894531
# ---------no execute --------
# current price is  62.599998474121094
# ---------no execute --------
# current price is  60.189998626708984
# current price is  62.060001373291016
# current price is  59.619998931884766
# current price is  62.040000915527344
# current price is  62.86000061035156
# current price is  64.12999725341797
# current price is  62.72999954223633
# current price is  63.34000015258789
# ---------no execute --------
# current price is  63.779998779296875
# ---------no execute --------
# current price is  63.9900016784668
# ---------no execute --------
# current price is  61.33000183105469
# current price is  61.70000076293945
# ---------no execute --------
# current price is  62.31999969482422
# ---------no execute --------
# current price is  62.380001068115234
# ---------no execute --------
# current price is  60.61000061035156
# ---------no execute --------
# current price is  61.08000183105469
# ---------no execute --------
# current price is  59.619998931884766
# current price is  59.869998931884766
# ---------no execute --------
# current price is  55.4900016784668
# current price is  57.18000030517578
# current price is  57.72999954223633
# ---------no execute --------
# current price is  58.779998779296875
# ---------no execute --------
# current price is  57.099998474121094
# ---------no execute --------
# current price is  57.810001373291016
# ---------no execute --------
# current price is  58.540000915527344
# ---------no execute --------
# current price is  59.31999969482422
# current price is  55.31999969482422
# current price is  55.4900016784668
# current price is  55.220001220703125
# current price is  57.40999984741211
# current price is  54.869998931884766
# current price is  56.849998474121094
# current price is  57.66999816894531
# ---------no execute --------
# current price is  58.560001373291016
# current price is  57.060001373291016
# ---------no execute --------
# current price is  57.11000061035156
# ---------no execute --------
# current price is  55.65999984741211
# current price is  58.459999084472656
# current price is  55.279998779296875
# current price is  58.38999938964844
# current price is  59.02000045776367
# ---------no execute --------
# current price is  59.08000183105469
# ---------no execute --------
# current price is  56.22999954223633
# current price is  56.380001068115234
# ---------no execute --------
# current price is  57.4900016784668
# ---------no execute --------
# current price is  58.59000015258789
# current price is  56.59000015258789
# current price is  58.45000076293945
# current price is  58.810001373291016
# ---------no execute --------
# current price is  61.290000915527344
# current price is  58.52000045776367
# ---------no execute --------
# current price is  61.08000183105469
# current price is  62.08000183105469
# current price is  62.849998474121094
# current price is  61.38999938964844
# current price is  62.779998779296875
# ---------no execute --------
# current price is  63.04999923706055
# current price is  63.349998474121094
# ---------no execute --------
# current price is  62.279998779296875
# ---------no execute --------
# current price is  62.93000030517578
# ---------no execute --------
# current price is  61.5
# current price is  62.65999984741211
# ---------no execute --------
# current price is  61.290000915527344
# ---------no execute --------
# current price is  62.0099983215332
# ---------no execute --------
# current price is  62.77000045776367
# ---------no execute --------
# current price is  65.12000274658203
# current price is  62.63999938964844
# ---------no execute --------
# current price is  65.06999969482422
# current price is  65.08000183105469
# ---------no execute --------
# current price is  65.62999725341797
# current price is  64.58999633789062
# ---------no execute --------
# current price is  65.26000213623047
# ---------no execute --------
# current price is  65.30999755859375
# ---------no execute --------
# current price is  65.66000366210938
# ---------no execute --------
# current price is  64.4800033569336
# ---------no execute --------
# current price is  64.81999969482422
# ---------no execute --------
# current price is  62.79999923706055
# current price is  66.4000015258789
# current price is  62.779998779296875
# current price is  66.0199966430664
# current price is  66.0
# ---------no execute --------
# current price is  66.19000244140625
# ---------no execute --------
# current price is  65.0
# ---------no execute --------
# current price is  65.5999984741211
# ---------no execute --------
# current price is  64.95999908447266
# ---------no execute --------
# current price is  65.55999755859375
# ---------no execute --------
# current price is  64.37999725341797
# ---------no execute --------
# current price is  64.62999725341797
# ---------no execute --------
# current price is  65.16000366210938
# ---------no execute --------
# current price is  65.83000183105469
# ---------no execute --------
# current price is  64.33000183105469
# ---------no execute --------
# current price is  64.54000091552734
# ---------no execute --------
# current price is  63.970001220703125
# current price is  65.2300033569336
# ---------no execute --------
# current price is  63.20000076293945
# ---------no execute --------
# current price is  65.0999984741211
# ---------no execute --------
# current price is  67.1500015258789
# current price is  67.8499984741211
# current price is  65.1500015258789
# current price is  65.93000030517578
# ---------no execute --------
# current price is  66.0199966430664
# ---------no execute --------
# current price is  68.80999755859375
# current price is  65.97000122070312
# ---------no execute --------
# current price is  68.68000030517578
# current price is  65.91999816894531
# current price is  66.54000091552734
# ---------no execute --------
# current price is  65.30999755859375
# current price is  65.68000030517578
# ---------no execute --------
# current price is  66.83999633789062
# current price is  66.9000015258789
# ---------no execute --------
# current price is  61.779998779296875
# current price is  62.939998626708984
# current price is  62.95000076293945
# ---------no execute --------
# current price is  63.0099983215332
# ---------no execute --------
# current price is  59.31999969482422
# current price is  60.22999954223633
# current price is  60.869998931884766
# ---------no execute --------
# current price is  62.290000915527344
# ---------no execute --------
# current price is  59.90999984741211
# current price is  61.43000030517578
# ---------no execute --------
# current price is  62.0
# current price is  62.83000183105469
# current price is  61.2400016784668
# current price is  62.27000045776367
# ---------no execute --------
# current price is  60.900001525878906
# ---------no execute --------
# current price is  65.0
# current price is  60.84000015258789
# current price is  64.75
# current price is  65.08999633789062
# current price is  65.38999938964844
# ---------no execute --------
# current price is  64.30000305175781
# ---------no execute --------
# current price is  65.33000183105469
# ---------no execute --------
# current price is  65.25
# ---------no execute --------
# current price is  66.56999969482422
# current price is  64.98999786376953
# ---------no execute --------
# current price is  66.52999877929688
# ---------no execute --------
# current price is  67.05000305175781
# current price is  67.5999984741211
# ---------no execute --------
# current price is  66.6500015258789
# ---------no execute --------
# current price is  67.18000030517578
# ---------no execute --------
# current price is  66.95999908447266
# ---------no execute --------
# current price is  67.8499984741211
# ---------no execute --------
# current price is  66.4000015258789
# ---------no execute --------
# current price is  67.36000061035156
# ---------no execute --------
# current price is  67.30000305175781
# ---------no execute --------
# current price is  68.0999984741211
# ---------no execute --------
# current price is  67.0199966430664
# ---------no execute --------
# current price is  67.30000305175781
# ---------no execute --------
# current price is  65.95999908447266
# ---------no execute --------
# current price is  66.55000305175781
# ---------no execute --------
# current price is  65.0199966430664
# current price is  65.7300033569336
# ---------no execute --------
# current price is  66.08999633789062
# ---------no execute --------
# current price is  67.37000274658203
# current price is  65.44999694824219
# ---------no execute --------
# current price is  65.54000091552734
# ---------no execute --------
# current price is  66.26000213623047
# ---------no execute --------
# current price is  66.98999786376953
# ---------no execute --------
# current price is  65.2300033569336
# current price is  66.75
# ---------no execute --------
# current price is  65.23999786376953
# ---------no execute --------
# current price is  65.80000305175781
# ---------no execute --------
# current price is  63.08000183105469
# current price is  64.31999969482422
# ---------no execute --------
# current price is  65.73999786376953
# current price is  66.1500015258789
# ---------no execute --------
# current price is  64.52999877929688
# ---------no execute --------
# current price is  64.91000366210938
# ---------no execute --------
# current price is  64.38999938964844
# ---------no execute --------
# current price is  65.41999816894531
# ---------no execute --------
# current price is  63.209999084472656
# current price is  64.9000015258789
# ---------no execute --------
# current price is  65.37000274658203
# ---------no execute --------
# current price is  65.43000030517578
# current price is  64.0
# current price is  64.7699966430664
# ---------no execute --------
# current price is  65.33999633789062
# ---------no execute --------
# current price is  66.62000274658203
# current price is  65.20999908447266
# ---------no execute --------
# current price is  65.44000244140625
# ---------no execute --------
# current price is  65.0
# ---------no execute --------
# current price is  66.41999816894531
# ---------no execute --------
# current price is  64.79000091552734
# ---------no execute --------
# current price is  66.19999694824219
# ---------no execute --------
# current price is  65.87000274658203
# ---------no execute --------
# current price is  67.26000213623047
# current price is  65.56999969482422
# ---------no execute --------
# current price is  65.87000274658203
# ---------no execute --------
# current price is  66.56999969482422
# ---------no execute --------
# current price is  67.87000274658203
# ---------no execute --------
# current price is  66.5
# ---------no execute --------
# current price is  67.69999694824219
# ---------no execute --------
# current price is  68.79000091552734
# current price is  69.75
# current price is  68.41999816894531
# ---------no execute --------
# current price is  69.73999786376953
# ---------no execute --------
# current price is  70.31999969482422
# ---------no execute --------
# current price is  70.56999969482422
# ---------no execute --------
# current price is  69.63999938964844
# ---------no execute --------
# current price is  70.05000305175781
# ---------no execute --------
# current price is  70.41000366210938
# ---------no execute --------
# current price is  72.5999984741211
# current price is  70.3499984741211
# ---------no execute --------
# current price is  72.5
# current price is  72.05999755859375
# ---------no execute --------
# current price is  73.36000061035156
# ---------no execute --------
# current price is  71.3499984741211
# ---------no execute --------
# current price is  72.08999633789062
# ---------no execute --------
# current price is  71.81999969482422
# ---------no execute --------
# current price is  72.94999694824219
# ---------no execute --------
# current price is  71.56999969482422
# ---------no execute --------
# current price is  72.30000305175781
# ---------no execute --------
# current price is  71.66999816894531
# ---------no execute --------
# current price is  72.02999877929688
# ---------no execute --------
# current price is  70.2300033569336
# current price is  71.44000244140625
# ---------no execute --------
# current price is  71.0
# ---------no execute --------
# current price is  71.02999877929688
# ---------no execute --------
# current price is  67.91999816894531
# current price is  68.5999984741211
# ---------no execute --------
# current price is  68.72000122070312
# ---------no execute --------
# current price is  68.93000030517578
# ---------no execute --------
# current price is  65.37999725341797
# current price is  66.7300033569336
# current price is  65.36000061035156
# current price is  67.69000244140625
# current price is  65.22000122070312
# current price is  66.06999969482422
# ---------no execute --------
# current price is  67.08999633789062
# current price is  67.22000122070312
# ---------no execute --------
# current price is  65.52999877929688
# ---------no execute --------
# current price is  66.6500015258789
# ---------no execute --------
# current price is  65.7699966430664
# ---------no execute --------
# current price is  68.4800033569336
# current price is  65.30000305175781
# current price is  68.12999725341797
# current price is  67.8499984741211
# ---------no execute --------
# current price is  67.98999786376953
# ---------no execute --------
# current price is  65.79000091552734
# current price is  67.54000091552734
# ---------no execute --------
# current price is  68.69999694824219
# current price is  70.0199966430664
# current price is  68.66999816894531
# ---------no execute --------
# current price is  69.54000091552734
# ---------no execute --------
# current price is  69.79000091552734
# ---------no execute --------
# current price is  70.13999938964844
# ---------no execute --------
# current price is  68.20999908447266
# ---------no execute --------
# current price is  69.01000213623047
# ---------no execute --------
# current price is  68.62000274658203
# ---------no execute --------
# current price is  68.83000183105469
# ---------no execute --------
# current price is  65.86000061035156
# current price is  66.0999984741211
# current price is  66.23999786376953
# ---------no execute --------
# current price is  68.6500015258789
# current price is  66.13999938964844
# current price is  67.66999816894531
# ---------no execute --------
# current price is  67.69999694824219
# ---------no execute --------
# current price is  68.18000030517578
# current price is  66.19000244140625
# current price is  67.5199966430664
# ---------no execute --------
# current price is  68.81999969482422
# current price is  69.9800033569336
# current price is  68.36000061035156
# ---------no execute --------
# current price is  69.63999938964844
# ---------no execute --------
# current price is  70.26000213623047
# ---------no execute --------
# current price is  70.58000183105469
# ---------no execute --------
# current price is  68.30999755859375
# ---------no execute --------
# current price is  68.52999877929688
# ---------no execute --------
# current price is  67.11000061035156
# current price is  69.19000244140625
# ---------no execute --------
# current price is  66.23999786376953
# current price is  69.12000274658203
# current price is  68.98999786376953
# ---------no execute --------
# current price is  69.52999877929688
# current price is  68.30999755859375
# ---------no execute --------
# current price is  69.4000015258789
# ---------no execute --------
# current price is  69.45999908447266
# ---------no execute --------
# current price is  71.47000122070312
# current price is  69.11000061035156
# current price is  69.33000183105469
# ---------no execute --------
# current price is  70.36000061035156
# ---------no execute --------
# current price is  71.9800033569336
# current price is  70.2300033569336
# ---------no execute --------
# current price is  71.25
# ---------no execute --------
# current price is  70.63999938964844
# ---------no execute --------
# current price is  71.75
# ---------no execute --------
# current price is  70.27999877929688
# ---------no execute --------
# current price is  71.13999938964844
# ---------no execute --------
# current price is  72.5
# current price is  73.16999816894531
# ---------no execute --------
# current price is  71.08000183105469
# ---------no execute --------
# current price is  71.55000305175781
# ---------no execute --------
# current price is  71.36000061035156
# ---------no execute --------
# current price is  72.76000213623047
# ---------no execute --------
# current price is  70.63999938964844
# current price is  71.13999938964844
# ---------no execute --------
# current price is  72.01000213623047
# ---------no execute --------
# current price is  72.5
# current price is  71.02999877929688
# ---------no execute --------
# current price is  71.3499984741211
# ---------no execute --------
# current price is  70.5
# current price is  70.58000183105469
# ---------no execute --------
# current price is  65.69999694824219
# current price is  67.27999877929688
# current price is  67.19999694824219
# ---------no execute --------
# current price is  67.83000183105469
# ---------no execute --------
# current price is  62.81999969482422
# current price is  64.75
# current price is  63.84000015258789
# current price is  65.25
# ---------no execute --------
# current price is  61.2400016784668
# current price is  63.59000015258789
# ---------no execute --------
# current price is  63.66999816894531
# ---------no execute --------
# current price is  65.5999984741211
# current price is  63.189998626708984
# ---------no execute --------
# current price is  64.08000183105469
# ---------no execute --------
# current price is  62.9900016784668
# ---------no execute --------
# current price is  63.060001373291016
# ---------no execute --------
# current price is  55.439998626708984
# current price is  55.77000045776367
# current price is  55.0099983215332
# current price is  57.25
# current price is  51.83000183105469
# current price is  53.5099983215332
# current price is  57.779998779296875
# ---------no execute --------
# current price is  58.52000045776367
# current price is  54.79999923706055
# current price is  58.029998779296875
# current price is  57.459999084472656
# ---------no execute --------
# current price is  57.709999084472656
# ---------no execute --------
# current price is  55.25
# current price is  55.84000015258789
# ---------no execute --------
# current price is  57.63999938964844
# ---------no execute --------
# current price is  61.16999816894531
# current price is  57.349998474121094
# ---------no execute --------
# current price is  60.650001525878906
# current price is  61.68000030517578
# current price is  61.779998779296875
# current price is  58.95000076293945
# current price is  60.849998474121094
# ---------no execute --------
# current price is  60.060001373291016
# ---------no execute --------
# current price is  60.130001068115234
# ---------no execute --------
# current price is  55.810001373291016
# current price is  56.630001068115234
# current price is  57.790000915527344
# ---------no execute --------
# current price is  59.38999938964844
# current price is  55.790000915527344
# current price is  56.400001525878906
# current price is  57.40999984741211
# ---------no execute --------
# current price is  58.58000183105469
# current price is  55.970001220703125
# current price is  57.25
# ---------no execute --------
# current price is  54.189998626708984
# current price is  57.47999954223633
# current price is  52.22999954223633
# current price is  56.619998931884766
# ---------no execute --------
# current price is  56.40999984741211
# ---------no execute --------
# current price is  56.70000076293945
# ---------no execute --------
# current price is  48.68000030517578
# current price is  48.91999816894531
# current price is  51.09000015258789
# current price is  54.77000045776367
# current price is  50.43000030517578
# current price is  53.939998626708984
# current price is  48.400001525878906
# current price is  52.83000183105469
# ---------no execute --------
# current price is  47.47999954223633
# current price is  49.75
# current price is  51.97999954223633
# current price is  52.599998474121094
# current price is  43.84000015258789
# current price is  47.09000015258789
# current price is  46.2400016784668
# current price is  49.04999923706055
# ---------no execute --------
# current price is  45.56999969482422
# current price is  48.90999984741211
# ---------no execute --------
# current price is  51.25
# current price is  53.65999984741211
# current price is  51.25
# ---------no execute --------
# current price is  52.209999084472656
# current price is  52.66999816894531
# current price is  54.619998931884766
# current price is  51.439998626708984
# current price is  54.4900016784668
# current price is  53.95000076293945
# ---------no execute --------
# current price is  54.93000030517578
# current price is  50.79999923706055
# current price is  52.04999923706055
# current price is  52.08000183105469
# ---------no execute --------
# current price is  52.13999938964844
# ---------no execute --------
# current price is  49.7599983215332
# current price is  51.540000915527344
# ---------no execute --------
# current price is  51.40999984741211
# ---------no execute --------
# current price is  53.529998779296875
# current price is  51.27000045776367
# current price is  52.630001068115234
# current price is  54.5099983215332
# current price is  57.560001373291016
# current price is  54.16999816894531
# ---------no execute --------
# current price is  57.470001220703125
# current price is  56.790000915527344
# ---------no execute --------
# current price is  57.31999969482422
# current price is  55.65999984741211
# current price is  56.4900016784668
# ---------no execute --------
# current price is  54.91999816894531
# ---------no execute --------
# current price is  55.279998779296875
# ---------no execute --------
# current price is  52.290000915527344
# current price is  53.619998931884766
# ---------no execute --------
# current price is  52.5
# current price is  52.790000915527344
# ---------no execute --------
# current price is  48.59000015258789
# current price is  48.90999984741211
# current price is  49.470001220703125
# current price is  51.5
# current price is  48.439998626708984
# current price is  48.88999938964844
# current price is  50.279998779296875
# ---------no execute --------
# current price is  50.81999969482422
# current price is  46.880001068115234
# current price is  47.650001525878906
# current price is  47.38999938964844
# ---------no execute --------
# current price is  50.61000061035156
# current price is  46.209999084472656
# current price is  50.20000076293945
# current price is  48.7599983215332
# ---------no execute --------
# current price is  50.400001525878906
# current price is  48.119998931884766
# current price is  49.650001525878906
# ---------no execute --------
# current price is  48.91999816894531
# ---------no execute --------
# current price is  49.150001525878906
# ---------no execute --------
# current price is  44.400001525878906
# current price is  44.88999938964844
# current price is  41.720001220703125
# current price is  44.2400016784668
# current price is  40.70000076293945
# current price is  42.400001525878906
# current price is  44.029998779296875
# ---------no execute --------
# current price is  44.619998931884766
# current price is  43.119998931884766
# current price is  43.349998474121094
# ---------no execute --------
# current price is  42.279998779296875
# current price is  43.720001220703125
# current price is  42.25
# current price is  42.38999938964844
# ---------no execute --------
# current price is  44.18000030517578
# current price is  45.380001068115234
# current price is  43.619998931884766
# current price is  45.29999923706055
# current price is  44.619998931884766
# ---------no execute --------
# current price is  46.119998931884766
# current price is  43.88999938964844
# current price is  45.77000045776367
# current price is  46.79999923706055
# current price is  50.15999984741211
# current price is  46.0
# current price is  50.11000061035156
# current price is  49.52000045776367
# current price is  50.66999816894531
# current price is  48.47999954223633
# ---------no execute --------
# current price is  49.650001525878906
# ---------no execute --------
# current price is  49.84000015258789
# ---------no execute --------
# current price is  50.84000015258789
# current price is  49.130001068115234
# current price is  50.689998626708984
# current price is  54.08000183105469
# current price is  54.29999923706055
# current price is  52.25
# ---------no execute --------
# current price is  53.290000915527344
# ---------no execute --------
# current price is  52.54999923706055
# ---------no execute --------
# current price is  52.9900016784668
# ---------no execute --------
# current price is  47.06999969482422
# current price is  47.43000030517578
# current price is  44.40999984741211
# current price is  48.220001220703125
# ...
# ---------no execute --------
# current price is  92.04000091552734
# ---------no execute --------
# current price is  94.05000305175781
# ---------no execute --------
# current price is  96.97000122070312
# ---------no execute --------
# current price is  97.2300033569336
# ---------no execute --------
# current price is  91.95999908447266
# ---------no execute --------
# current price is  93.91999816894531
# ---------no execute --------
# current price is  93.91000366210938
# ---------no execute --------
# current price is  97.55000305175781
# ---------no execute --------
# current price is  93.51000213623047
# ---------no execute --------
# current price is  97.26000213623047
# ---------no execute --------
# current price is  99.37000274658203
# ---------no execute --------
# current price is  102.62000274658203
# current price is  98.66000366210938
# ---------no execute --------
# current price is  99.80000305175781
# ---------no execute --------
# current price is  98.9000015258789
# ---------no execute --------
# current price is  100.47000122070312
# ---------no execute --------
# current price is  91.8499984741211
# ---------no execute --------
# current price is  93.91999816894531
# ---------no execute --------
# current price is  93.91000366210938
# ---------no execute --------
# current price is  96.72000122070312
# ---------no execute --------
# current price is  90.73999786376953
# ---------no execute --------
# current price is  96.41000366210938
# ---------no execute --------
# current price is  96.0199966430664
# ---------no execute --------
# current price is  96.30000305175781
# ---------no execute --------
# current price is  88.9000015258789
# ---------no execute --------
# current price is  89.4800033569336
# ---------no execute --------
# current price is  89.20999908447266
# ---------no execute --------
# current price is  92.43000030517578
# ---------no execute --------
# current price is  86.27999877929688
# ---------no execute --------
# current price is  92.33999633789062
# ---------no execute --------
# current price is  92.31999969482422
# ---------no execute --------
# current price is  98.4800033569336
# ---------no execute --------
# current price is  92.12999725341797
# ---------no execute --------
# current price is  97.6500015258789
# ---------no execute --------
# current price is  97.86000061035156
# ---------no execute --------
# current price is  102.47000122070312
# ---------no execute --------
# current price is  97.23999786376953
# ---------no execute --------
# current price is  101.13999938964844
# ---------no execute --------
# current price is  104.29000091552734
# ---------no execute --------
# current price is  105.87000274658203
# ---------no execute --------
# current price is  102.73999786376953
# ---------no execute --------
# current price is  103.29000091552734
# ---------no execute --------
# current price is  107.30000305175781
# ---------no execute --------
# current price is  111.58000183105469
# ---------no execute --------
# current price is  107.29000091552734
# ---------no execute --------
# current price is  110.87999725341797
# ---------no execute --------
# current price is  110.55000305175781
# ---------no execute --------
# current price is  114.16000366210938
# ---------no execute --------
# current price is  108.23999786376953
# ---------no execute --------
# current price is  108.69999694824219
# ---------no execute --------
# current price is  110.43000030517578
# ---------no execute --------
# current price is  112.94000244140625
# ---------no execute --------
# current price is  108.48999786376953
# ---------no execute --------
# current price is  112.87999725341797
# ---------no execute --------
# current price is  115.41000366210938
# ---------no execute --------
# current price is  116.66999816894531
# ---------no execute --------
# current price is  109.86000061035156
# ---------no execute --------
# current price is  115.69999694824219
# ---------no execute --------
# current price is  115.41999816894531
# ---------no execute --------
# current price is  118.44999694824219
# ---------no execute --------
# current price is  111.88999938964844
# ---------no execute --------
# current price is  118.1500015258789
# ---------no execute --------
# current price is  122.05000305175781
# current price is  125.94999694824219
# ---------no execute --------
# current price is  109.69000244140625
# ---------no execute --------
# current price is  110.8499984741211
# ---------no execute --------
# current price is  107.58999633789062
# ---------no execute --------
# current price is  113.72000122070312
# ---------no execute --------
# current price is  103.38999938964844
# ---------no execute --------
# current price is  113.19999694824219
# ---------no execute --------
# current price is  114.86000061035156
# ---------no execute --------
# current price is  116.22000122070312
# ---------no execute --------
# current price is  109.38999938964844
# ---------no execute --------
# current price is  113.76000213623047
# ---------no execute --------
# current price is  110.04000091552734
# ---------no execute --------
# current price is  112.36000061035156
# ---------no execute --------
# current price is  106.98999786376953
# ---------no execute --------
# current price is  111.31999969482422
# ---------no execute --------
# current price is  112.16000366210938
# ---------no execute --------
# current price is  113.04000091552734
# ---------no execute --------
# current price is  109.0
# ---------no execute --------
# current price is  111.83999633789062
# ---------no execute --------
# current price is  112.80000305175781
# ---------no execute --------
# current price is  122.2300033569336
# ---------no execute --------
# current price is  111.08999633789062
# ---------no execute --------
# current price is  121.36000061035156
# ---------no execute --------
# current price is  123.58999633789062
# ---------no execute --------
# current price is  123.66999816894531
# ---------no execute --------
# current price is  116.4000015258789
# ---------no execute --------
# current price is  117.4800033569336
# ---------no execute --------
# current price is  118.16999816894531
# ---------no execute --------
# current price is  120.12999725341797
# ---------no execute --------
# current price is  115.6500015258789
# ---------no execute --------
# current price is  118.83999633789062
# ---------no execute --------
# current price is  118.30999755859375
# ---------no execute --------
# current price is  119.23999786376953
# ---------no execute --------
# current price is  107.56999969482422
# ---------no execute --------
# current price is  109.52999877929688
# ---------no execute --------
# current price is  104.51000213623047
# ---------no execute --------
# current price is  108.16000366210938
# ---------no execute --------
# current price is  101.01000213623047
# ---------no execute --------
# current price is  106.29000091552734
# ---------no execute --------
# current price is  108.58999633789062
# ---------no execute --------
# current price is  112.55000305175781
# ---------no execute --------
# current price is  107.4800033569336
# ---------no execute --------
# current price is  112.0
# ---------no execute --------
# current price is  111.08000183105469
# ---------no execute --------
# current price is  111.70999908447266
# ---------no execute --------
# current price is  107.37000274658203
# ---------no execute --------
# current price is  107.79000091552734
# ---------no execute --------
# current price is  109.69000244140625
# ---------no execute --------
# current price is  112.61000061035156
# ---------no execute --------
# current price is  109.1500015258789
# ---------no execute --------
# current price is  111.45999908447266
# ---------no execute --------
# current price is  108.9000015258789
# ---------no execute --------
# current price is  113.97000122070312
# ---------no execute --------
# current price is  107.36000061035156
# ---------no execute --------
# current price is  113.2699966430664
# ---------no execute --------
# current price is  119.31999969482422
# ---------no execute --------
# current price is  119.5
# ---------no execute --------
# current price is  112.87999725341797
# ---------no execute --------
# current price is  119.37999725341797
# ---------no execute --------
# current price is  122.25
# ---------no execute --------
# current price is  125.12999725341797
# ---------no execute --------
# current price is  122.05999755859375
# ---------no execute --------
# current price is  123.83000183105469
# ---------no execute --------
# current price is  123.31999969482422
# ---------no execute --------
# current price is  125.62000274658203
# ---------no execute --------
# current price is  122.33999633789062
# ---------no execute --------
# current price is  125.44000244140625
# ---------no execute --------
# current price is  126.1500015258789
# ---------no execute --------
# current price is  127.06999969482422
# ---------no execute --------
# current price is  124.91000366210938
# ---------no execute --------
# current price is  126.44000244140625
# ---------no execute --------
# current price is  126.11000061035156
# ---------no execute --------
# current price is  131.92999267578125
# ---------no execute --------
# current price is  125.22000122070312
# ---------no execute --------
# current price is  131.27999877929688
# ---------no execute --------
# current price is  130.6199951171875
# ---------no execute --------
# current price is  131.82000732421875
# ---------no execute --------
# current price is  123.69000244140625
# ---------no execute --------
# current price is  126.98999786376953
# ---------no execute --------
# current price is  127.2699966430664
# ---------no execute --------
# current price is  127.61000061035156
# ---------no execute --------
# current price is  120.16999816894531
# ---------no execute --------
# current price is  125.27999877929688
# ---------no execute --------
# current price is  123.55999755859375
# ---------no execute --------
# current price is  125.44999694824219
# ---------no execute --------
# current price is  117.38999938964844
# ---------no execute --------
# current price is  118.16999816894531
# ---------no execute --------
# current price is  121.0999984741211
# ---------no execute --------
# current price is  128.36000061035156
# ---------no execute --------
# current price is  121.0999984741211
# ---------no execute --------
# current price is  127.01000213623047
# ---------no execute --------
# current price is  128.0800018310547
# ---------no execute --------
# current price is  131.17999267578125
# ---------no execute --------
# current price is  126.52999877929688
# ---------no execute --------
# current price is  127.9000015258789
# ---------no execute --------
# current price is  128.66000366210938
# ---------no execute --------
# current price is  129.19000244140625
# ---------no execute --------
# current price is  125.41000366210938
# ---------no execute --------
# current price is  127.52999877929688
# ---------no execute --------
# current price is  129.8699951171875
# ---------no execute --------
# current price is  132.36000061035156
# ---------no execute --------
# current price is  129.66000366210938
# ---------no execute --------
# current price is  131.74000549316406
# ---------no execute --------
# current price is  133.42999267578125
# ---------no execute --------
# current price is  136.39999389648438
# ---------no execute --------
# current price is  131.2899932861328
# ---------no execute --------
# current price is  135.61000061035156
# ---------no execute --------
# current price is  135.58999633789062
# ---------no execute --------
# current price is  137.2100067138672
# ---------no execute --------
# current price is  132.2899932861328
# ---------no execute --------
# current price is  132.9600067138672
# ---------no execute --------
# current price is  131.75
# ---------no execute --------
# current price is  139.19000244140625
# ---------no execute --------
# current price is  131.1699981689453
# ---------no execute --------
# current price is  138.42999267578125
# ---------no execute --------
# current price is  138.66000366210938
# ---------no execute --------
# current price is  142.00999450683594
# ---------no execute --------
# current price is  137.7899932861328
# ---------no execute --------
# current price is  141.32000732421875
# ---------no execute --------
# current price is  146.2100067138672
# ---------no execute --------
# current price is  147.55999755859375
# ---------no execute --------
# current price is  140.44000244140625
# ---------no execute --------
# current price is  143.94000244140625
# ---------no execute --------
# current price is  142.8300018310547
# ---------no execute --------
# current price is  147.4499969482422
# ---------no execute --------
# current price is  142.07000732421875
# ---------no execute --------
# current price is  147.3000030517578
# ---------no execute --------
# current price is  149.27000427246094
# current price is  157.0500030517578
# ---------no execute --------
# current price is  149.0800018310547
# ---------no execute --------
# current price is  156.72999572753906
# ---------no execute --------
# current price is  158.5800018310547
# ---------no execute --------
# current price is  159.8699951171875
# ---------no execute --------
# current price is  151.5800018310547
# ---------no execute --------
# current price is  155.30999755859375
# ---------no execute --------
# current price is  157.2899932861328
# ---------no execute --------
# current price is  158.72999572753906
# ---------no execute --------
# current price is  155.14999389648438
# ---------no execute --------
# current price is  157.7100067138672
# ---------no execute --------
# current price is  158.5399932861328
# ---------no execute --------
# current price is  164.5399932861328
# ---------no execute --------
# current price is  157.82000732421875
# ---------no execute --------
# current price is  161.36000061035156
# ---------no execute --------
# current price is  165.9199981689453
# ---------no execute --------
# current price is  169.97000122070312
# ---------no execute --------
# current price is  162.9499969482422
# ---------no execute --------
# current price is  169.74000549316406
# ---------no execute --------
# current price is  175.47999572753906
# ---------no execute --------
# current price is  175.6699981689453
# ---------no execute --------
# current price is  164.6699981689453
# ---------no execute --------
# current price is  174.52999877929688
# ---------no execute --------
# current price is  166.72999572753906
# ---------no execute --------
# current price is  167.39999389648438
# ---------no execute --------
# current price is  142.82000732421875
# ---------no execute --------
# current price is  147.72999572753906
# ---------no execute --------
# current price is  145.3800048828125
# ---------no execute --------
# current price is  150.3000030517578
# ---------no execute --------
# current price is  123.86000061035156
# ---------no execute --------
# current price is  141.63999938964844
# ---------no execute --------
# current price is  124.94999694824219
# ---------no execute --------
# current price is  133.97000122070312
# ---------no execute --------
# current price is  121.05999755859375
# current price is  121.62000274658203
# ---------no execute --------
# current price is  129.02999877929688
# ---------no execute --------
# current price is  135.1999969482422
# ---------no execute --------
# current price is  125.66999816894531
# ---------no execute --------
# current price is  132.07000732421875
# ---------no execute --------
# current price is  136.52000427246094
# ---------no execute --------
# current price is  138.38999938964844
# ---------no execute --------
# current price is  121.73999786376953
# ---------no execute --------
# current price is  124.43000030517578
# ---------no execute --------
# current price is  127.0
# ---------no execute --------
# current price is  128.19000244140625
# ---------no execute --------
# current price is  116.80999755859375
# ---------no execute --------
# current price is  121.70999908447266
# ---------no execute --------
# current price is  127.0
# ---------no execute --------
# current price is  130.80999755859375
# ---------no execute --------
# current price is  125.08000183105469
# ---------no execute --------
# current price is  127.9800033569336
# ---------no execute --------
# current price is  133.3300018310547
# ---------no execute --------
# current price is  134.86000061035156
# ---------no execute --------
# current price is  132.6999969482422
# ---------no execute --------
# current price is  134.74000549316406
# ---------no execute --------

# %%
cols=['year','discount','model','profit','totalMoneyBuy','totalmoneySell','max_money_needed','max_loss','openShares','year_start_price','year_end_price']
df=pd.DataFrame(columns=cols)
iterations=itertools.product(years,discount_factors,models)
for it in iterations:
    year,discount,model=it
    name='{}-{}-{}'.format(year,discount,model.__name__)
    print(name)
    stockTrade=stockTrades[name]
    #check_results(stockTrades[name])
    profit=stockTrades[name].get_profit(stockTrades[name].currentPrice)
    totalMoneyBuy=stockTrades[name].totalMoneyBuy
    totalmoneySell=stockTrades[name].totalmoneySell
    max_money_needed=stockTrades[name].max_money_needed
    max_loss=stockTrades[name].max_loss
    openShares=stockTrades[name].openShares
    start_price=df_years[year]['Open'][0]
    end_price=df_years[year]['Close'][-1]
    df.loc[len(df)]=[year,discount,model.__name__,profit,totalMoneyBuy,totalmoneySell,max_money_needed,max_loss,openShares,start_price,end_price]
    #print('year start price: ', start_price)
    #print('year end price: ',end_price)
# Out:
# 2018-2-model_1
# 2018-2-model_2
# 2018-6-model_1
# 2018-6-model_2
# 2018-10-model_1
# 2018-10-model_2
# 2018-14-model_1
# 2018-14-model_2
# 2018-18-model_1
# 2018-18-model_2
# 2019-2-model_1
# 2019-2-model_2
# 2019-6-model_1
# 2019-6-model_2
# 2019-10-model_1
# 2019-10-model_2
# 2019-14-model_1
# 2019-14-model_2
# 2019-18-model_1
# 2019-18-model_2
# 2020-2-model_1
# 2020-2-model_2
# 2020-6-model_1
# 2020-6-model_2
# 2020-10-model_1
# 2020-10-model_2
# 2020-14-model_1
# 2020-14-model_2
# 2020-18-model_1
# 2020-18-model_2

# %%
df.head()
# Out:
#    year discount    model    profit  totalMoneyBuy  totalmoneySell  \
# 0  2018        2  model_1 -43848.45  770791.510330       562966.98
# 1  2018        2  model_2 -17082.87  528020.456736       432227.58
# 2  2018        6  model_1  -4698.56  185258.050116       128481.25
# 3  2018        6  model_2  -1506.06  126435.656780        97371.84
# 4  2018       10  model_1  -2139.51   85247.650139        51698.22
#
#    max_money_needed  max_loss openShares  year_start_price  year_end_price
# 0     221821.330330 -74623.40       4427         46.966667       37.040001
# 1     106168.746736 -32286.72       2125         46.966667       37.040001
# 2      63755.390116 -15322.88       1406         46.966667       37.040001
# 3      34283.236780  -7366.29        744         46.966667       37.040001
# 4      36129.810139  -8334.83        848         46.966667       37.040001

# %%
#df.loc[df['year'] == 2020]
df['profit_over_maxMoney']=df['profit']/df['max_money_needed']
df['maxLoss_over_maxMoney']=df['max_loss']/df['max_money_needed']

# %%
df.sort_values(['profit_over_maxMoney'],ascending=False)
#df.sort_values('maxLoss_over_maxMoney',ascending=False)
# Out:
#     year discount    model    profit  totalMoneyBuy  totalmoneySell  \
# 19  2019       18  model_2   5607.38   13922.889913        14510.37
# 24  2020       10  model_1  44677.83   90952.319935        74188.71
# 18  2019       18  model_1   7475.68   20718.299650        18240.73
# 16  2019       14  model_1   5878.07   20792.179913        23035.15
# 28  2020       18  model_1  18166.97   26553.799959        20871.79
# 22  2020        6  model_1  58924.83  176244.320055       146240.75
# 26  2020       14  model_1  25743.39   42306.949959        33422.16
# 25  2020       10  model_2  22375.01   69876.779935        63147.95
# 15  2019       10  model_2   4726.81   24051.869824        26874.58
# 29  2020       18  model_2   9805.38   19882.889959        18100.63
# 14  2019       10  model_1   6693.77   33514.770005        34755.89
# 17  2019       14  model_2   5315.81   18048.159763        17911.32
# 27  2020       14  model_2  14175.40   31982.509959        28506.97
# 12  2019        6  model_1  11674.18   84823.099849        84899.58
# 23  2020        6  model_2  29592.60  140670.669871       127685.43
# 13  2019        6  model_2   7611.46   61992.619488        66834.48
# 20  2020        2  model_1  95738.82  540986.560031       475908.87
# 10  2019        2  model_1  33618.05  482786.639821       454088.69
# 11  2019        2  model_2  17306.46  356017.369768       354542.48
# 21  2020        2  model_2  45258.83  459634.999852       428496.25
# 9   2018       18  model_2    709.40   17942.346710        10910.39
# 8   2018       18  model_1    722.52   26059.506710        14040.27
# 5   2018       10  model_2     89.62   55991.606799        39635.47
# 6   2018       14  model_1   -656.10   32813.890027        16526.91
# 3   2018        6  model_2  -1506.06  126435.656780        97371.84
# 4   2018       10  model_1  -2139.51   85247.650139        51698.22
# 2   2018        6  model_1  -4698.56  185258.050116       128481.25
# 7   2018       14  model_2   -908.06   24040.976754        12576.52
# 1   2018        2  model_2 -17082.87  528020.456736       432227.58
# 0   2018        2  model_1 -43848.45  770791.510330       562966.98
#
#     max_money_needed  max_loss openShares  year_start_price  year_end_price  \
# 19       4342.939913      0.00         58         34.779999       86.550003
# 24      38730.409935 -13292.34        456         88.709999      134.800095
# 18       6746.489650   -373.29        115         34.779999       86.550003
# 16       5785.569913   -524.81         42         34.779999       86.550003
# 28      18170.839959  -6553.64        177         88.709999      134.800095
# 22      62575.740055 -25053.85        660         88.709999      134.800095
# 26      27543.879959  -9859.35        257         88.709999      134.800095
# 25      26326.069935 -10235.41        216         88.709999      134.800095
# 15       5659.059824   -176.30         22         34.779999       86.550003
# 29      12492.449959  -4844.46         86         88.709999      134.800095
# 14       8562.510005   -518.89         63         34.779999       86.550003
# 17       7061.239763    -71.93         63         34.779999       86.550003
# 27      19213.719959  -7503.47        131         88.709999      134.800095
# 12      16521.249849   -354.95        134         34.779999       86.550003
# 23      43922.459871 -18761.59        316         88.709999      134.800095
# 13      11480.019488   -333.55         32         34.779999       86.550003
# 20     149043.020031 -67824.80       1193         88.709999      134.800095
# 10      63468.469821  -4442.31        720         34.779999       86.550003
# 11      36097.279768  -3106.55        217         34.779999       86.550003
# 21     114680.639852 -55538.12        567         88.709999      134.800095
# 9        8848.386710  -1020.55        209         46.966667       37.040001
# 8       14577.066710  -2045.95        344         46.966667       37.040001
# 5       18169.376799  -3265.54        444         46.966667       37.040001
# 6       16286.980027  -3491.94        422         46.966667       37.040001
# 3       34283.236780  -7366.29        744         46.966667       37.040001
# 4       36129.810139  -8334.83        848         46.966667       37.040001
# 2       63755.390116 -15322.88       1406         46.966667       37.040001
# 7       11464.456754  -2823.26        285         46.966667       37.040001
# 1      106168.746736 -32286.72       2125         46.966667       37.040001
# 0      221821.330330 -74623.40       4427         46.966667       37.040001
#
#     profit_over_maxMoney  maxLoss_over_maxMoney
# 19              1.291148               0.000000
# 24              1.153559              -0.343202
# 18              1.108084              -0.055331
# 16              1.015988              -0.090710
# 28              0.999787              -0.360668
# 22              0.941656              -0.400376
# 26              0.934632              -0.357951
# 25              0.849918              -0.388794
# 15              0.835264              -0.031154
# 29              0.784904              -0.387791
# 14              0.781753              -0.060600
# 17              0.752815              -0.010187
# 27              0.737775              -0.390527
# 12              0.706616              -0.021484
# 23              0.673746              -0.427153
# 13              0.663018              -0.029055
# 20              0.642357              -0.455069
# 10              0.529681              -0.069992
# 11              0.479439              -0.086061
# 21              0.394651              -0.484285
# 9               0.080173              -0.115337
# 8               0.049566              -0.140354
# 5               0.004932              -0.179728
# 6              -0.040284              -0.214401
# 3              -0.043930              -0.214866
# 4              -0.059217              -0.230691
# 2              -0.073697              -0.240339
# 7              -0.079207              -0.246262
# 1              -0.160903              -0.304108
# 0              -0.197675              -0.336412
